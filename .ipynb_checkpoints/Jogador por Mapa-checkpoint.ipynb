# %%
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings('ignore')

# %%
df_placar2 = pd.read_csv("vlr_placar2.csv")
df_placar2
# Out:
#                                                     URL      Mapa  \
# 0     https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...     Haven
# 1     https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...     Abyss
# 2     https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...   AllMaps
# 3     https://www.vlr.gg/596399/envy-vs-evil-geniuse...     Abyss
# 4     https://www.vlr.gg/596399/envy-vs-evil-geniuse...   Corrode
# ...                                                 ...       ...
# 1567  https://www.vlr.gg/189059/evil-geniuses-vs-nrg...   AllMaps
# 1568  https://www.vlr.gg/189055/loud-vs-nrg-esports-...    Ascent
# 1569  https://www.vlr.gg/189055/loud-vs-nrg-esports-...      Bind
# 1570  https://www.vlr.gg/189055/loud-vs-nrg-esports-...  Fracture
# 1571  https://www.vlr.gg/189055/loud-vs-nrg-esports-...   AllMaps
#
#               Time1  Mapas_T1  Score_T1          Time2  Mapas_T2  Score_T2  \
# 0              LOUD       NaN         7         Cloud9       NaN        13
# ...

# %%
df_stats2 = pd.read_csv("vlr_stats2.csv")
df_stats2
# Out:
#                                                      URL  Mapa_Num      Mapa  \
# 0      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 1      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 2      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 3      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 4      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# ...                                                  ...       ...       ...
# 10896  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10897  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10898  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10899  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10900  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
#
# ...

# %% [markdown]
# # Tratamento de Dados Duplicados

# %%
df_stats2 = pd.read_csv("vlr_stats2.csv")
df_stats2


chave = ['URL', 'Jogador', 'Mapa_Num']

dups = df_stats2[df_stats2.duplicated(subset=chave, keep=False)]
print(f"Linhas duplicadas: {len(dups)}")
print(f"Combinações únicas duplicadas: {dups.groupby(chave).ngroups}")
display(dups.sort_values(chave))


df_stats2 = df_stats2.drop_duplicates(subset=chave, keep='first').reset_index(drop=True)
print(f"\nShape final: {df_stats2.shape}")
# Out:
# Linhas duplicadas: 0
# Combinações únicas duplicadas: 0
# Empty DataFrame
# Columns: [URL, Mapa_Num, Mapa, Jogador, Time, Agente, R, ACS, K, D, A, +/-, KAST, ADR, HS%, FK, FD, +/-_FK_FD]
# Index: []
# Shape final: (10901, 18)

# %%
df_stats2.to_csv("vlr_stats2.csv", index=False)
df_stats2
# Out:
#                                                      URL  Mapa_Num      Mapa  \
# 0      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 1      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 2      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 3      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 4      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# ...                                                  ...       ...       ...
# 10896  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10897  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10898  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10899  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10900  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
#
# ...

# %% [markdown]
# # Juntas os DF's Placar e Stats

# %%
df_merged = df_stats2.merge(
    df_placar2,
    left_on=['URL', 'Mapa'],
    right_on=['URL', 'Mapa'],
    how='left'
).query("Mapa != 'AllMaps'")

nome_para_tag = {
    'Sentinels': 'SEN',
    'NRG': 'NRG',
    'Cloud9': 'C9',
    'FURIA': 'FUR',
    'LEVIATÁN': 'LEV',
    'Evil Geniuses': 'EG',
    '100 Thieves': '100T',
    'KRÜ Esports': 'KRU',
    'VISA KRÜ(KRÜ Esports)': 'KRU',
    'G2 Esports': 'G2',
    'ENVY': 'ENVY',
    'MIBR': 'MIBR',
    'LOUD': 'LOUD',
    '2Game Esports': '2G'
}

for col in ['Time', 'Time1', 'Time2', 'Vencedor']:
    df_merged[col] = df_merged[col].map(nome_para_tag).fillna(df_merged[col])


df_merged['Vencedor'] = (df_merged['Vencedor'] == df_merged['Time']).astype(int)

df_merged.drop(columns=['URL','Mapa_Num','Time1','Time2','Mapas_T1', 'Mapas_T2', 'Score_T1','Score_T2'], inplace=True)
df_merged.rename(columns={'Vencedor': 'target'}, inplace=True)

#df_merged.to_csv("status_individual.csv", index=False)
df_merged
# Out:
#            Mapa   Jogador  Time     Agente     R    ACS   K   D   A  +/-  \
# 0         Haven    Darker  LOUD      Viper  1.12  256.0  18  16   6    2
# 1         Haven  cauanzin  LOUD       Sova  0.98  209.0  15  13   3    2
# 2         Haven    Virtyy  LOUD       Yoru  0.70  178.0  14  16   4   -2
# 3         Haven   pANcada  LOUD       Omen  0.67  145.0  11  13   1   -2
# 4         Haven     lukxo  LOUD    Killjoy  0.65  192.0  13  16   3   -3
# ...         ...       ...   ...        ...   ...    ...  ..  ..  ..  ...
# 10896  Fracture  crashies   NRG       Skye  1.24  212.0  19  17  11    2
# 10897  Fracture       s0m   NRG  Brimstone  1.24  240.0  19  18  12    1
# 10898  Fracture    Victor   NRG    Killjoy  0.83  168.0  16  17   1   -1
# 10899  Fracture    ardiis   NRG       Jett  0.81  210.0  15  19   4   -4
# 10900  Fracture   FiNESSE   NRG     Breach  0.65  136.0  10  19  10   -9
#
#        KAST    ADR   HS%   FK   FD  +/-_FK_FD  target
# ...

# %% [markdown]
# # Descobrir as Features mais importantes para um time ganhar

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

df_merged = pd.read_csv("merged_status_placar.csv")
df = df_merged.copy()
df['Win'] = (df['Time'] == df['Vencedor']).astype(int)
cols_drop = [
    'Mapa',
    'Time',
    'Agente',
    'Vencedor',
    'Adversario',
    'Score_Time',
    'Score_Adv',
    'Mapas_Time',
    'Mapas_Adv',
    'URL',
    'Jogador'
]

df_model = df.drop(columns=cols_drop)

X = df_model.drop(columns=['Win'])
y = df_model['Win']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(X_train, y_train)

importances = model.feature_importances_

feat_importance = pd.Series(importances, index=X.columns)
feat_importance = feat_importance.sort_values(ascending=False)

print(feat_importance.head(20))
# Out:
# +/-          0.142999
# KAST         0.121974
# D            0.116403
# R            0.103842
# ACS          0.093438
# ADR          0.082862
# HS%          0.068935
# A            0.066584
# K            0.064496
# +/-_FK_FD    0.042758
# FD           0.037090
# FK           0.034781
# Mapa_Num     0.023839
# dtype: float64

# %% [markdown]
# # Calculo de Impacto do Jogador por Cada Partida

# %%
df_merged2 = df_stats2.merge(
    df_placar2,
    left_on=['URL', 'Mapa'],
    right_on=['URL', 'Mapa'],
    how='left'
).query("Mapa != 'AllMaps'")

nome_para_tag = {
    'Sentinels': 'SEN',
    'NRG': 'NRG',
    'Cloud9': 'C9',
    'FURIA': 'FUR',
    'LEVIATÁN': 'LEV',
    'Evil Geniuses': 'EG',
    '100 Thieves': '100T',
    'KRÜ Esports': 'KRU',
    'VISA KRÜ(KRÜ Esports)': 'KRU',
    'G2 Esports': 'G2',
    'ENVY': 'ENVY',
    'MIBR': 'MIBR',
    'LOUD': 'LOUD',
    '2Game Esports': '2G'
}

for col in ['Time', 'Time1', 'Time2', 'Vencedor']:
    df_merged2[col] = df_merged2[col].map(nome_para_tag).fillna(df_merged2[col])


df_merged2['Vencedor'] = (df_merged2['Vencedor'] == df_merged2['Time']).astype(int)

df_merged2.rename(columns={'Vencedor': 'target'}, inplace=True)

df_merged2
# Out:
#                                                      URL  Mapa_Num      Mapa  \
# 0      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 1      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 2      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 3      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# 4      https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0     Haven
# ...                                                  ...       ...       ...
# 10896  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10897  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10898  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10899  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
# 10900  https://www.vlr.gg/189055/loud-vs-nrg-esports-...         3  Fracture
#
# ...

# %%
df_merged2.describe()
# Out:
#            Mapa_Num             R           ACS             K             D  \
# count  11240.000000  11230.000000  11230.000000  11240.000000  11240.000000
# mean       1.438612      0.997397    196.414693     14.570196     14.585587
# std        1.263688      0.332194     56.939685      5.242806      3.591243
# min        0.000000      0.010000     27.000000      1.000000      3.000000
# 25%        0.000000      0.770000    157.000000     11.000000     13.000000
# 50%        2.000000      0.980000    193.000000     14.000000     15.000000
# 75%        2.000000      1.210000    232.000000     18.000000     17.000000
# max        5.000000      2.490000    460.000000     47.000000     32.000000
#
#                  A           +/-          KAST           ADR           HS%  \
# count  11240.00000  11240.000000  11230.000000  11230.000000  11230.000000
# mean       6.12589     -0.015391     72.002315    128.978094     27.367676
# ...

# %%
REF_MEDIANO = {
    'Mapa_Num':   2.0,
    'R':          0.98,
    'ACS':        193.0,
    'K':          14.0,
    'D':          15.0,
    'A':          6.0,
    '+/-':        0.0,
    'KAST':       73.0,
    'ADR':        127.0,
    'HS':        26.0,
    'FK':         2.0,
    'FD':         2.0,
    '+/-_FK_FD':  0.0,
    'Score_T1':   13.0,
    'Score_T2':   13.0
}

PESOS = {
    '+/-':        0.143,
    'KAST':       0.122,
    'D':          0.116,
    'R':          0.104,
    'ACS':        0.093,
    'ADR':        0.083,
    'HS':        0.069,
    'A':          0.067,
    'K':          0.064,
    '+/-_FK_FD':  0.043,
    'FD':         0.037,
    'FK':         0.035,
    'Mapa_Num':   0.024
}


def calcular_impacto(r, acs, kast, adr, hs, tot_k, tot_d, tot_fk, tot_fd, jogos):
    def clip(x, min_v=0.5, max_v=1.5):
        return max(min(x, max_v), min_v)

    kd_rate  = (tot_k - tot_d) / jogos if jogos > 0 else 0
    fkd_rate = (tot_fk - tot_fd) / jogos if jogos > 0 else 0

    scores = {
        'R':          clip(r    / REF_MEDIANO['R']),
        'ACS':        clip(acs  / REF_MEDIANO['ACS']),
        'ADR':        clip(adr  / REF_MEDIANO['ADR']),
        'KAST':       clip(kast / REF_MEDIANO['KAST']),
        'HS':         clip(math.sqrt(hs / REF_MEDIANO['HS'])),
        '+/-':        clip(1 + (kd_rate  / 2)),
        '+/-_FK_FD':  clip(1 + (fkd_rate / 1)),
    }

    score = sum(PESOS[m] * scores[m] for m in scores)
    return round(score, 3)


def calcular_impacto_por_mapa(df: pd.DataFrame) -> pd.DataFrame:
    
    colunas_numericas = ['R', 'ACS', 'KAST', 'ADR', 'HS%', 'K', 'D', 'FK', 'FD']
    df = df.copy()
    for col in colunas_numericas:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    def calcular_linha(row):
        return calcular_impacto(
            r      = row['R'],
            acs    = row['ACS'],
            kast   = row['KAST'],
            adr    = row['ADR'],
            hs     = row['HS%'],
            tot_k  = row['K'],
            tot_d  = row['D'],
            tot_fk = row['FK'],
            tot_fd = row['FD'],
            jogos  = 1          
        )

    df['Impacto'] = df.apply(calcular_linha, axis=1)

    colunas_id = ['URL', 'Mapa_Num', 'Mapa', 'Jogador', 'Time', 'Agente']
    colunas_existentes = [c for c in colunas_id if c in df.columns]
    demais = [c for c in df.columns if c not in colunas_existentes and c != 'Impacto']

    df = df[colunas_existentes + demais + ['Impacto']]

    return df


df_impacto = calcular_impacto_por_mapa(df_merged2)
df_impacto.drop(columns=['URL','Mapa_Num','Mapas_T1', 'Mapas_T2'], inplace=True)

df_impacto.to_csv("df_impacto_cada_mapa.csv", index=False)

df_impacto.head(5)
# Out:
#     Mapa   Jogador  Time   Agente     R    ACS   K   D  A  +/-  ...   HS%  \
# 0  Haven    Darker  LOUD    Viper  1.12  256.0  18  16  6    2  ...  30.0
# 1  Haven  cauanzin  LOUD     Sova  0.98  209.0  15  13  3    2  ...  26.0
# 2  Haven    Virtyy  LOUD     Yoru  0.70  178.0  14  16  4   -2  ...  35.0
# 3  Haven   pANcada  LOUD     Omen  0.67  145.0  11  13  1   -2  ...  27.0
# 4  Haven     lukxo  LOUD  Killjoy  0.65  192.0  13  16  3   -3  ...  35.0
#
#     FK   FD  +/-_FK_FD  Time1  Score_T1 Time2  Score_T2 target  Impacto
# 0  2.0  1.0        1.0   LOUD         7    C9        13      0    0.821
# 1  0.0  1.0       -1.0   LOUD         7    C9        13      0    0.734
# 2  2.0  3.0       -1.0   LOUD         7    C9        13      0    0.492
# 3  0.0  3.0       -3.0   LOUD         7    C9        13      0    0.478
# 4  4.0  4.0        0.0   LOUD         7    C9        13      0    0.538
#
# [5 rows x 22 columns]

# %%
df_impacto[df_impacto['Jogador'] == 'Darker']
# Out:
#          Mapa Jogador  Time   Agente     R    ACS   K   D   A  +/-  ...   HS%  \
# 0       Haven  Darker  LOUD    Viper  1.12  256.0  18  16   6    2  ...  30.0
# 1       Haven  Darker  LOUD    Viper  1.12  256.0  18  16   6    2  ...  30.0
# 42      Abyss  Darker  LOUD    Astra  0.95  166.0  15  16   8   -1  ...  31.0
# 43      Abyss  Darker  LOUD    Astra  0.95  166.0  15  16   8   -1  ...  31.0
# 564    Breeze  Darker  LOUD     Kayo  1.06  187.0  16  16   5    0  ...  18.0
# 565    Breeze  Darker  LOUD     Kayo  1.06  187.0  16  16   5    0  ...  18.0
# 608      Bind  Darker  LOUD     Tejo  0.54  157.0  10  17   3   -7  ...  29.0
# 609      Bind  Darker  LOUD     Tejo  0.54  157.0  10  17   3   -7  ...  29.0
# 628     Pearl  Darker  LOUD     Tejo  0.32   71.0   3  13   3  -10  ...   6.0
# 629     Pearl  Darker  LOUD     Tejo  0.32   71.0   3  13   3  -10  ...   6.0
# 1140    Haven  Darker  LOUD    Viper  1.20  288.0  18  15   4    3  ...  29.0
# ...

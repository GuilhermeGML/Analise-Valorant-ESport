# %% [markdown]
# # CODIGO DEFINITIVO FEITO POR MIM

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.vlr.gg/596408/mibr-vs-furia-vct-2026-americas-kickoff-ubf"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

lista = [0, 2, 3, 4, 5]  # índices dos mapas

dfs = []  # lista para armazenar DataFrames de cada mapa

for i in lista:
    
    data = []  # reinicia para cada mapa
    
    all_maps_block = soup.select(".vm-stats-game")[i]
    tables = all_maps_block.select(".wf-table-inset")
    
    for table in tables:
        rows = table.find_all("tr")
        for row in rows:
            cells = [c.get_text(strip=True) for c in row.find_all(["th","td"])]
            if cells:
                data.append(cells)
    
    df = pd.DataFrame(data)
    
    # Remove linhas indesejadas (ajuste se necessário)
    df = df.drop(index=[0, 6]).reset_index(drop=True)
    
    # Renomeia colunas
    df.columns = [
        "Jogador", "", "R", "ACS", "K", "D", "A",
        "+/-", "KAST", "ADR", "HS%", "FK", "FD", "+/-_2"
    ]
    
    df = df.drop(columns=[""])
    
    # Formatação
    df["R"] = df["R"].str[:4]
    df["ACS"] = df["ACS"].str[:3]
    df["K"] = df["K"].str[:2]
    df["D"] = df["D"].str[1:3]
    df["A"] = df["A"].str[:2]
    df["+/-"] = df["+/-"].str.extract(r'([-+]?\d+)').astype(int)
    df["KAST"] = df["KAST"].str[:3]
    df["ADR"] = df["ADR"].str[:3]
    df["HS%"] = df["HS%"].str[:3]
    df["FK"] = df["FK"].str.extract(r'(\d+)').astype(int)
    df["FD"] = df["FD"].str.extract(r'(\d+)').astype(int)
    df["+/-_2"] = df["+/-_2"].str.extract(r'([-+]?\d+)').astype(int)

    # Converte tipos
    df["R"] = df["R"].astype(str).str.extract(r'(\d+\.\d+)').astype(float)
    df["ACS"] = df["ACS"].astype(str).str.extract(r'^(\d{2,3})').astype(int)
    df["K"] = df["K"].astype(str).str.extract(r'^(\d{1,2})').astype(int)
    df["D"] = df["D"].astype(str).str.extract(r'^(\d{1,2})').astype(int)
    df["A"] = df["A"].astype(str).str.extract(r'^(\d{1,2})').astype(int)
    df["+/-"] = df["+/-"].astype(str).str.extract(r'([-+]?\d+)').astype(int)
    df["KAST"] = df["KAST"].astype(str).str.extract(r'^(\d{1,3})').astype(int)
    df["HS%"] = df["HS%"].astype(str).str.extract(r'^(\d{1,3})').astype(int)
    df["ADR"] = df["ADR"].astype(str).str.extract(r'^(\d{2,3})').astype(int)
    df["FK"] = df["FK"].astype(str).str[0].astype(int)
    df["FD"] = df["FD"].astype(str).str[0].astype(int)
    df["+/-_2"] = df["+/-_2"].astype(str).str.extract(r'([-+]?\d+)').astype(int)

    # adiciona coluna do mapa
    df["Mapa"] = i
    
    dfs.append(df)

# Junta todos os mapas
df_final = pd.concat(dfs, ignore_index=True)

# Exporta para CSV
df_final.to_csv("vlr2.csv", index=False)

print("CSV salvo com sucesso!")
# Out:
# CSV salvo com sucesso!

# %% [markdown]
# #  CODIGO ADAPTADO E MELHORADO POR IA

# %% [markdown]
# # Coleta Automatizada

# %%
import re
import sys
import time
import os

import gspread
import pandas as pd
import requests
from bs4 import BeautifulSoup
from google.oauth2.service_account import Credentials

# ─────────────────────────────────────────────
#  CONFIGURAÇÃO
# ─────────────────────────────────────────────

CREDENTIALS_FILE = "teste-coleta-489718-87d9ed749c61.json"
SPREADSHEET_ID   = "1wAcPW4R9jIfi9fkgOO-sPhQGxJQJQxvAp2t5Ff0upMg"
ABA_URLS         = "Página1"
ABA_STATS        = "Stats"
OUTPUT_CSV       = "vlr_stats2.csv"
DELAY            = 3

SCOPES = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive",
]

# ─────────────────────────────────────────────
#  GOOGLE SHEETS
# ─────────────────────────────────────────────

def conectar_sheets():
    creds  = Credentials.from_service_account_file(CREDENTIALS_FILE, scopes=SCOPES)
    client = gspread.authorize(creds)
    return client.open_by_key(SPREADSHEET_ID)


def ler_urls_pendentes(sheet):
    aba     = sheet.worksheet(ABA_URLS)
    valores = aba.get_all_values()
    pendentes = []
    for i, row in enumerate(valores, start=1):
        if not row or not row[0].strip():
            continue
        url    = row[0].strip()
        status = row[1].strip().lower() if len(row) > 1 else ""
        if status not in ("ok", "erro"):
            pendentes.append((i, url))
    return aba, pendentes


def marcar_status(aba, linha, status):
    aba.update_cell(linha, 2, status)


def _expandir_aba(aba, linhas_necessarias):
    """Expande a aba automaticamente se o número de linhas for insuficiente."""
    props = aba.spreadsheet.fetch_sheet_metadata()
    for s in props["sheets"]:
        if s["properties"]["title"] == aba.title:
            atual = s["properties"]["gridProperties"]["rowCount"]
            if linhas_necessarias > atual:
                aba.add_rows(linhas_necessarias - atual + 1000)
                print(f"     📐 Aba expandida para {linhas_necessarias + 1000} linhas")
            break


def escrever_stats(sheet, df):
    try:
        aba = sheet.worksheet(ABA_STATS)
    except gspread.exceptions.WorksheetNotFound:
        aba = sheet.add_worksheet(title=ABA_STATS, rows=1000, cols=20)

    existentes = aba.get_all_values()
    df_limpo   = df.fillna("")
    novas_rows = df_limpo.values.tolist()

    if not existentes:
        todas = [df_limpo.columns.tolist()] + novas_rows
        _expandir_aba(aba, len(todas))
        aba.update(values=todas, range_name="A1")
    else:
        proxima = len(existentes) + 1
        _expandir_aba(aba, proxima + len(novas_rows))
        aba.update(values=novas_rows, range_name=f"A{proxima}")

    print(f"     ✔ {len(df)} linhas escritas na aba '{ABA_STATS}'")


def salvar_csv(df, caminho):
    existe = os.path.isfile(caminho)
    df.to_csv(caminho, mode="a", index=False, header=not existe)
    print(f"     ✔ {len(df)} linhas salvas em '{caminho}'")


# ─────────────────────────────────────────────
#  SCRAPING
# ─────────────────────────────────────────────

def get_map_name(block):
    header = block.select_one(".vm-stats-game-header")
    if header:
        text  = header.get_text(" ", strip=True)
        match = re.search(
            r'\b(Bind|Haven|Split|Ascent|Icebox|Breeze|Fracture|Pearl|Lotus|Sunset|Abyss|Corrode)\b',
            text, re.IGNORECASE,
        )
        if match:
            return match.group(1).capitalize()
    return "AllMaps"


def bloco_tem_dados(block):
    for row in block.select(".wf-table-inset tr"):
        cells = row.select("td")
        if cells and any(c.get_text(strip=True) for c in cells):
            return True
    return False


def detectar_mapas(soup):
    blocks  = soup.select(".vm-stats-game")
    validos = [i for i, b in enumerate(blocks) if bloco_tem_dados(b)]
    return validos


def mod_both(cell):
    el = cell.select_one(".mod-both")
    return el.get_text(strip=True) if el else cell.get_text(strip=True)


def extrair_jogador(cell):
    nome_el = cell.select_one(".text-of")
    time_el = cell.select_one(".ge-text-light")
    nome = nome_el.get_text(strip=True) if nome_el else ""
    time = time_el.get_text(strip=True) if time_el else ""
    return nome, time


def extrair_agente(cell):
    img = cell.select_one("img")
    if not img:
        return None
    nome = img.get("title") or img.get("alt") or ""
    if nome:
        return nome.strip().capitalize()
    src   = img.get("src", "")
    match = re.search(r'/([^/]+?)(?:_\w+)?\.(?:png|webp|jpg)$', src, re.IGNORECASE)
    return match.group(1).replace("-", " ").capitalize() if match else None


def p_int(text, pattern=r'(\d+)'):
    m = re.search(pattern, text)
    return int(m.group(1)) if m else None

def p_float(text):
    m = re.search(r'(\d+\.\d+)', text)
    return float(m.group(1)) if m else None

def p_signed(text):
    m = re.search(r'([+-]?\d+)', text)
    return int(m.group(1)) if m else None


def extrair_linha(row):
    cells = row.select("td")
    if len(cells) < 13:
        return None

    jogador, time = extrair_jogador(cells[0])
    if not jogador:
        return None

    def v(i):
        return mod_both(cells[i])

    def kda(i):
        m = re.search(r'^(\d+)', v(i).strip())
        return int(m.group(1)) if m else None

    return {
        "Jogador":   jogador,
        "Time":      time,
        "Agente":    extrair_agente(cells[1]),
        "R":         p_float(v(2)),
        "ACS":       p_int(v(3)),
        "K":         kda(4),
        "D":         kda(5),
        "A":         kda(6),
        "+/-":       p_signed(v(7)),
        "KAST":      p_int(v(8)),
        "ADR":       p_int(v(9)),
        "HS%":       p_int(v(10)),
        "FK":        p_int(v(11)),
        "FD":        p_int(v(12)),
        "+/-_FK_FD": p_signed(v(13)) if len(cells) > 13 else None,
    }


def extrair_dataframe(block, indice, nome_mapa, url):
    rows_data = []
    for table in block.select(".wf-table-inset"):
        for row in table.select("tr"):
            if row.select("th") and not row.select("td"):
                continue
            parsed = extrair_linha(row)
            if parsed:
                rows_data.append(parsed)

    if not rows_data:
        return None

    df = pd.DataFrame(rows_data)
    df.insert(0, "URL",      url)
    df.insert(1, "Mapa_Num", indice)
    df.insert(2, "Mapa",     nome_mapa)
    return df


def scrape_url(url):
    headers  = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers, timeout=15)
    response.raise_for_status()

    soup       = BeautifulSoup(response.text, "html.parser")
    all_blocks = soup.select(".vm-stats-game")

    if not all_blocks:
        return None

    indices = detectar_mapas(soup)
    if not indices:
        return None

    dfs = []
    for i in indices:
        nome = get_map_name(all_blocks[i])
        tipo = "All Maps" if nome == "AllMaps" else f"Mapa {i}"
        print(f"       [{tipo}] {nome}", end=" ... ")
        df = extrair_dataframe(all_blocks[i], i, nome, url)
        if df is not None:
            dfs.append(df)
            print(f"{len(df)} jogadores")
        else:
            print("sem dados")

    return pd.concat(dfs, ignore_index=True) if dfs else None


# ─────────────────────────────────────────────
#  EXECUÇÃO PRINCIPAL
# ─────────────────────────────────────────────

def main():
    print("🔗 Conectando ao Google Sheets...")
    sheet = conectar_sheets()

    aba_urls, pendentes = ler_urls_pendentes(sheet)

    if not pendentes:
        print("✅ Nenhuma URL pendente. Todas já foram coletadas.")
        return

    print(f"📋 {len(pendentes)} URL(s) pendente(s)\n")

    for linha, url in pendentes:
        print(f"  → Linha {linha}: {url}")
        try:
            df = scrape_url(url)
            if df is not None and not df.empty:
                escrever_stats(sheet, df)
                salvar_csv(df, OUTPUT_CSV)
                marcar_status(aba_urls, linha, "ok")
            else:
                print("     ⚠️  Sem dados (jogo não aconteceu ainda?)")
                marcar_status(aba_urls, linha, "erro")
        except Exception as e:
            print(f"     ❌ Erro: {e}")
            marcar_status(aba_urls, linha, "erro")

        time.sleep(DELAY)

    print(f"\n✅ Coleta finalizada! Dados salvos em '{OUTPUT_CSV}' e na planilha.")


if __name__ == "__main__":
    main()
# Out:
# 🔗 Conectando ao Google Sheets...
# 📋 312 URL(s) pendente(s)
#
#   → Linha 2: https://www.vlr.gg/596398/loud-vs-cloud9-vct-2026-americas-kickoff-ur1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Abyss ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 3: https://www.vlr.gg/596399/envy-vs-evil-geniuses-vct-2026-americas-kickoff-ur1
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 4: https://www.vlr.gg/596400/kr-esports-vs-furia-vct-2026-americas-kickoff-ur1
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#        [Mapa 3] Abyss ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 5: https://www.vlr.gg/596401/100-thieves-vs-leviat-n-vct-2026-americas-kickoff-ur1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 6: https://www.vlr.gg/596402/nrg-vs-cloud9-vct-2026-americas-kickoff-ur2
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 7: https://www.vlr.gg/596403/mibr-vs-envy-vct-2026-americas-kickoff-ur2
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 8: https://www.vlr.gg/596404/sentinels-vs-furia-vct-2026-americas-kickoff-ur2
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 9: https://www.vlr.gg/596405/g2-esports-vs-100-thieves-vct-2026-americas-kickoff-ur2
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 10: https://www.vlr.gg/596409/loud-vs-100-thieves-vct-2026-americas-kickoff-mr1
#        [Mapa 0] Breeze ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 11: https://www.vlr.gg/596410/evil-geniuses-vs-sentinels-vct-2026-americas-kickoff-mr1
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 12: https://www.vlr.gg/596411/kr-esports-vs-envy-vct-2026-americas-kickoff-mr1
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 13: https://www.vlr.gg/596412/leviat-n-vs-cloud9-vct-2026-americas-kickoff-mr1
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 14: https://www.vlr.gg/596413/100-thieves-vs-sentinels-vct-2026-americas-kickoff-mr2
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      📐 Aba expandida para 18302 linhas
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 15: https://www.vlr.gg/596414/envy-vs-cloud9-vct-2026-americas-kickoff-mr2
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 16: https://www.vlr.gg/596406/nrg-vs-mibr-vct-2026-americas-kickoff-ur3
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 17: https://www.vlr.gg/596407/furia-vs-g2-esports-vct-2026-americas-kickoff-ur3
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 18: https://www.vlr.gg/596419/loud-vs-evil-geniuses-vct-2026-americas-kickoff-lr1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Abyss ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 19: https://www.vlr.gg/596420/kr-esports-vs-leviat-n-vct-2026-americas-kickoff-lr1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 20: https://www.vlr.gg/596415/nrg-vs-100-thieves-vct-2026-americas-kickoff-mr3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 21: https://www.vlr.gg/596416/g2-esports-vs-cloud9-vct-2026-americas-kickoff-mr3
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 22: https://www.vlr.gg/596421/envy-vs-evil-geniuses-vct-2026-americas-kickoff-lr2
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 23: https://www.vlr.gg/596422/sentinels-vs-leviat-n-vct-2026-americas-kickoff-lr2
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 24: https://www.vlr.gg/596417/nrg-vs-g2-esports-vct-2026-americas-kickoff-mr4
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 25: https://www.vlr.gg/596423/100-thieves-vs-evil-geniuses-vct-2026-americas-kickoff-lr3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 26: https://www.vlr.gg/596424/cloud9-vs-leviat-n-vct-2026-americas-kickoff-lr3
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 27: https://www.vlr.gg/596408/mibr-vs-furia-vct-2026-americas-kickoff-ubf
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Abyss ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#        [Mapa 4] Breeze ... 10 jogadores
#        [Mapa 5] Split ... 10 jogadores
#      ✔ 60 linhas escritas na aba 'Stats'
#      ✔ 60 linhas salvas em 'vlr_stats2.csv'
#   → Linha 28: https://www.vlr.gg/596425/100-thieves-vs-cloud9-vct-2026-americas-kickoff-lr4
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Abyss ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 29: https://www.vlr.gg/596418/mibr-vs-g2-esports-vct-2026-americas-kickoff-mbf
#        [Mapa 0] Breeze ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Corrode ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 30: https://www.vlr.gg/596426/nrg-vs-100-thieves-vct-2026-americas-kickoff-lr5
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Abyss ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 31: https://www.vlr.gg/596427/mibr-vs-nrg-vct-2026-americas-kickoff-lbf
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#        [Mapa 4] Abyss ... 10 jogadores
#        [Mapa 5] Haven ... 10 jogadores
#      ✔ 60 linhas escritas na aba 'Stats'
#      ✔ 60 linhas salvas em 'vlr_stats2.csv'
#   → Linha 32: https://www.vlr.gg/645475/g2-esports-vs-mibr-vct-2026-americas-stage-1-w1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 33: https://www.vlr.gg/645477/envy-vs-loud-vct-2026-americas-stage-1-w1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 34: https://www.vlr.gg/645478/cloud9-vs-leviat-n-vct-2026-americas-stage-1-w1
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 35: https://www.vlr.gg/645480/cloud9-vs-envy-vct-2026-americas-stage-1-w2
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 36: https://www.vlr.gg/645482/g2-esports-vs-leviat-n-vct-2026-americas-stage-1-w2
#        [Mapa 0] Breeze ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 37: https://www.vlr.gg/645483/mibr-vs-loud-vct-2026-americas-stage-1-w2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 38: https://www.vlr.gg/645486/leviat-n-vs-envy-vct-2026-americas-stage-1-w3
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 39: https://www.vlr.gg/645487/g2-esports-vs-loud-vct-2026-americas-stage-1-w3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 40: https://www.vlr.gg/645491/mibr-vs-cloud9-vct-2026-americas-stage-1-w3
#        [Mapa 0] Breeze ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 41: https://www.vlr.gg/645493/leviat-n-vs-mibr-vct-2026-americas-stage-1-w4
#        [Mapa 0] Breeze ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 42: https://www.vlr.gg/645496/loud-vs-cloud9-vct-2026-americas-stage-1-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 43: https://www.vlr.gg/645497/g2-esports-vs-envy-vct-2026-americas-stage-1-w4
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      📐 Aba expandida para 19322 linhas
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 44: https://www.vlr.gg/645500/g2-esports-vs-cloud9-vct-2026-americas-stage-1-w5
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 45: https://www.vlr.gg/645501/envy-vs-mibr-vct-2026-americas-stage-1-w5
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 46: https://www.vlr.gg/645502/loud-vs-leviat-n-vct-2026-americas-stage-1-w5
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 47: https://www.vlr.gg/645474/sentinels-vs-kr-esports-vct-2026-americas-stage-1-w1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 48: https://www.vlr.gg/645476/100-thieves-vs-evil-geniuses-vct-2026-americas-stage-1-w1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 49: https://www.vlr.gg/645479/furia-vs-nrg-vct-2026-americas-stage-1-w1
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 50: https://www.vlr.gg/645481/furia-vs-evil-geniuses-vct-2026-americas-stage-1-w2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 51: https://www.vlr.gg/645484/nrg-vs-kr-esports-vct-2026-americas-stage-1-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 52: https://www.vlr.gg/645485/100-thieves-vs-sentinels-vct-2026-americas-stage-1-w2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 53: https://www.vlr.gg/645488/furia-vs-kr-esports-vct-2026-americas-stage-1-w3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 54: https://www.vlr.gg/645489/nrg-vs-100-thieves-vct-2026-americas-stage-1-w3
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 55: https://www.vlr.gg/645490/evil-geniuses-vs-sentinels-vct-2026-americas-stage-1-w3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 56: https://www.vlr.gg/645492/evil-geniuses-vs-nrg-vct-2026-americas-stage-1-w4
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 57: https://www.vlr.gg/645494/kr-esports-vs-100-thieves-vct-2026-americas-stage-1-w4
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 58: https://www.vlr.gg/645495/furia-vs-sentinels-vct-2026-americas-stage-1-w4
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 59: https://www.vlr.gg/645498/kr-esports-vs-evil-geniuses-vct-2026-americas-stage-1-w5
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 60: https://www.vlr.gg/645503/sentinels-vs-nrg-vct-2026-americas-stage-1-w5
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Breeze ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 61: https://www.vlr.gg/645499/furia-vs-100-thieves-vct-2026-americas-stage-1-w5
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Breeze ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 62: https://www.vlr.gg/530902/leviat-n-vs-cloud9-vct-2025-americas-stage-2-ur1
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 63: https://www.vlr.gg/530906/sentinels-vs-cloud9-vct-2025-americas-stage-2-ubsf
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 64: https://www.vlr.gg/530903/g2-esports-vs-100-thieves-vct-2025-americas-stage-2-ur1
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 65: https://www.vlr.gg/530907/nrg-vs-g2-esports-vct-2025-americas-stage-2-ubsf
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 66: https://www.vlr.gg/530910/sentinels-vs-g2-esports-vct-2025-americas-stage-2-ubf
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 67: https://www.vlr.gg/530913/g2-esports-vs-nrg-vct-2025-americas-stage-2-gf
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 68: https://www.vlr.gg/530904/leviat-n-vs-kr-esports-vct-2025-americas-stage-2-lr1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 69: https://www.vlr.gg/530905/100-thieves-vs-evil-geniuses-vct-2025-americas-stage-2-lr1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 70: https://www.vlr.gg/530908/nrg-vs-leviat-n-vct-2025-americas-stage-2-lr2
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 71: https://www.vlr.gg/530909/cloud9-vs-100-thieves-vct-2025-americas-stage-2-lr2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 72: https://www.vlr.gg/530911/nrg-vs-cloud9-vct-2025-americas-stage-2-lr3
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      📐 Aba expandida para 20332 linhas
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 73: https://www.vlr.gg/530912/sentinels-vs-nrg-vct-2025-americas-stage-2-lbf
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#        [Mapa 3] Sunset ... 10 jogadores
#        [Mapa 4] Corrode ... 10 jogadores
#      ✔ 50 linhas escritas na aba 'Stats'
#      ✔ 50 linhas salvas em 'vlr_stats2.csv'
#   → Linha 74: https://www.vlr.gg/509801/cloud9-vs-furia-vct-2025-americas-stage-2-w1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 75: https://www.vlr.gg/509803/evil-geniuses-vs-2game-esports-vct-2025-americas-stage-2-w1
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 76: https://www.vlr.gg/509806/sentinels-vs-g2-esports-vct-2025-americas-stage-2-w1
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 77: https://www.vlr.gg/509807/2game-esports-vs-g2-esports-vct-2025-americas-stage-2-w2
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 78: https://www.vlr.gg/509811/cloud9-vs-evil-geniuses-vct-2025-americas-stage-2-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 79: https://www.vlr.gg/509808/furia-vs-sentinels-vct-2025-americas-stage-2-w2
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 80: https://www.vlr.gg/509813/2game-esports-vs-furia-vct-2025-americas-stage-2-w3
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 81: https://www.vlr.gg/509815/sentinels-vs-cloud9-vct-2025-americas-stage-2-w3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 82: https://www.vlr.gg/509817/g2-esports-vs-evil-geniuses-vct-2025-americas-stage-2-w3
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 83: https://www.vlr.gg/509819/cloud9-vs-2game-esports-vct-2025-americas-stage-2-w4
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 84: https://www.vlr.gg/509821/sentinels-vs-evil-geniuses-vct-2025-americas-stage-2-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 85: https://www.vlr.gg/509823/furia-vs-g2-esports-vct-2025-americas-stage-2-w4
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 86: https://www.vlr.gg/509827/furia-vs-evil-geniuses-vct-2025-americas-stage-2-w5
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 87: https://www.vlr.gg/509829/2game-esports-vs-sentinels-vct-2025-americas-stage-2-w5
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 88: https://www.vlr.gg/509830/g2-esports-vs-cloud9-vct-2025-americas-stage-2-w5
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 89: https://www.vlr.gg/509831/mibr-vs-loud-vct-2025-americas-stage-2-w5
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 90: https://www.vlr.gg/509826/100-thieves-vs-leviat-n-vct-2025-americas-stage-2-w5
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 91: https://www.vlr.gg/509825/kr-esports-vs-nrg-vct-2025-americas-stage-2-w5
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 92: https://www.vlr.gg/509824/loud-vs-100-thieves-vct-2025-americas-stage-2-w4
#        [Mapa 0] Sunset ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 93: https://www.vlr.gg/509822/leviat-n-vs-kr-esports-vct-2025-americas-stage-2-w4
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 94: https://www.vlr.gg/509820/mibr-vs-nrg-vct-2025-americas-stage-2-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 95: https://www.vlr.gg/509818/loud-vs-kr-esports-vct-2025-americas-stage-2-w3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 96: https://www.vlr.gg/509816/mibr-vs-100-thieves-vct-2025-americas-stage-2-w3
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 97: https://www.vlr.gg/509814/leviat-n-vs-nrg-vct-2025-americas-stage-2-w3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Icebox ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 98: https://www.vlr.gg/509812/mibr-vs-leviat-n-vct-2025-americas-stage-2-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 99: https://www.vlr.gg/509810/nrg-vs-loud-vct-2025-americas-stage-2-w2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Corrode ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 100: https://www.vlr.gg/509809/100-thieves-vs-kr-esports-vct-2025-americas-stage-2-w2
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 101: https://www.vlr.gg/509805/100-thieves-vs-nrg-vct-2025-americas-stage-2-w1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Sunset ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 102: https://www.vlr.gg/509804/mibr-vs-kr-esports-vct-2025-americas-stage-2-w1
#        [Mapa 0] Corrode ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      📐 Aba expandida para 21372 linhas
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 103: https://www.vlr.gg/509802/leviat-n-vs-loud-vct-2025-americas-stage-2-w1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Icebox ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 104: https://www.vlr.gg/475897/mibr-vs-100-thieves-champions-tour-2025-americas-stage-1-ubr1
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 105: https://www.vlr.gg/475899/kr-esports-vs-mibr-champions-tour-2025-americas-stage-1-ubsf
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 106: https://www.vlr.gg/475901/mibr-vs-sentinels-champions-tour-2025-americas-stage-1-ubf
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 107: https://www.vlr.gg/475902/sentinels-vs-g2-esports-champions-tour-2025-americas-stage-1-gf
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#        [Mapa 4] Ascent ... 10 jogadores
#      ✔ 50 linhas escritas na aba 'Stats'
#      ✔ 50 linhas salvas em 'vlr_stats2.csv'
#   → Linha 108: https://www.vlr.gg/475898/sentinels-vs-cloud9-champions-tour-2025-americas-stage-1-ubr1
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 109: https://www.vlr.gg/475900/g2-esports-vs-sentinels-champions-tour-2025-americas-stage-1-ubsf
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 110: https://www.vlr.gg/475903/100-thieves-vs-nrg-esports-champions-tour-2025-americas-stage-1-lr1
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 111: https://www.vlr.gg/475904/cloud9-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr1
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 112: https://www.vlr.gg/475905/g2-esports-vs-100-thieves-champions-tour-2025-americas-stage-1-lr2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 113: https://www.vlr.gg/475906/kr-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 114: https://www.vlr.gg/475907/g2-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 115: https://www.vlr.gg/475908/mibr-vs-g2-esports-champions-tour-2025-americas-stage-1-lbf
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#        [Mapa 4] Ascent ... 10 jogadores
#      ✔ 50 linhas escritas na aba 'Stats'
#      ✔ 50 linhas salvas em 'vlr_stats2.csv'
#   → Linha 116: https://www.vlr.gg/459518/kr-esports-vs-loud-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 117: https://www.vlr.gg/459521/2game-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 118: https://www.vlr.gg/459522/sentinels-vs-100-thieves-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 119: https://www.vlr.gg/459524/sentinels-vs-kr-esports-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 120: https://www.vlr.gg/459525/100-thieves-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 121: https://www.vlr.gg/459527/loud-vs-2game-esports-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 122: https://www.vlr.gg/459529/evil-geniuses-vs-sentinels-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 123: https://www.vlr.gg/459530/100-thieves-vs-loud-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 124: https://www.vlr.gg/459531/2game-esports-vs-kr-esports-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 125: https://www.vlr.gg/459535/100-thieves-vs-2game-esports-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 126: https://www.vlr.gg/459538/sentinels-vs-loud-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 127: https://www.vlr.gg/459539/kr-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 128: https://www.vlr.gg/459543/sentinels-vs-2game-esports-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 129: https://www.vlr.gg/459544/kr-esports-vs-100-thieves-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 130: https://www.vlr.gg/459545/evil-geniuses-vs-loud-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 131: https://www.vlr.gg/459546/leviat-n-vs-nrg-esports-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      📐 Aba expandida para 22382 linhas
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 132: https://www.vlr.gg/459542/mibr-vs-furia-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 133: https://www.vlr.gg/459541/g2-esports-vs-cloud9-champions-tour-2025-americas-stage-1-w5
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 134: https://www.vlr.gg/459540/nrg-esports-vs-mibr-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 135: https://www.vlr.gg/459537/furia-vs-cloud9-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 136: https://www.vlr.gg/459536/g2-esports-vs-leviat-n-champions-tour-2025-americas-stage-1-w4
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 137: https://www.vlr.gg/459534/cloud9-vs-mibr-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 138: https://www.vlr.gg/459533/furia-vs-leviat-n-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 139: https://www.vlr.gg/459532/g2-esports-vs-nrg-esports-champions-tour-2025-americas-stage-1-w3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 140: https://www.vlr.gg/459528/leviat-n-vs-cloud9-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 141: https://www.vlr.gg/459526/g2-esports-vs-mibr-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 142: https://www.vlr.gg/459523/nrg-esports-vs-furia-champions-tour-2025-americas-stage-1-w2
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Fracture ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 143: https://www.vlr.gg/459520/mibr-vs-leviat-n-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 144: https://www.vlr.gg/459519/g2-esports-vs-furia-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 145: https://www.vlr.gg/459517/cloud9-vs-nrg-esports-champions-tour-2025-americas-stage-1-w1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 146: https://www.vlr.gg/427991/evil-geniuses-vs-loud-champions-tour-2025-americas-kickoff-ur1
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 147: https://www.vlr.gg/427992/mibr-vs-100-thieves-champions-tour-2025-americas-kickoff-ur1
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 148: https://www.vlr.gg/427993/nrg-esports-vs-cloud9-champions-tour-2025-americas-kickoff-ur1
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 149: https://www.vlr.gg/427994/2game-esports-vs-furia-champions-tour-2025-americas-kickoff-ur1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 150: https://www.vlr.gg/428003/furia-vs-evil-geniuses-champions-tour-2025-americas-kickoff-lr1
#        [Mapa 0] Abyss ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 151: https://www.vlr.gg/428004/cloud9-vs-mibr-champions-tour-2025-americas-kickoff-lr1
#        [Mapa 0] Lotus ... 10 jogadores
# ...
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 268: https://www.vlr.gg/183783/evil-geniuses-vs-100-thieves-champions-tour-2023-americas-league-w2
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 11 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 31 linhas escritas na aba 'Stats'
#      ✔ 31 linhas salvas em 'vlr_stats2.csv'
#   → Linha 269: https://www.vlr.gg/183785/cloud9-vs-100-thieves-champions-tour-2023-americas-league-w3
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 270: https://www.vlr.gg/183786/nrg-esports-vs-mibr-champions-tour-2023-americas-league-w3
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 271: https://www.vlr.gg/183787/leviat-n-vs-sentinels-champions-tour-2023-americas-league-w3
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 272: https://www.vlr.gg/183788/evil-geniuses-vs-kr-esports-champions-tour-2023-americas-league-w3
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Fracture ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 273: https://www.vlr.gg/183789/loud-vs-furia-champions-tour-2023-americas-league-w3
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 274: https://www.vlr.gg/183791/loud-vs-sentinels-champions-tour-2023-americas-league-w4
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 275: https://www.vlr.gg/183792/leviat-n-vs-mibr-champions-tour-2023-americas-league-w4
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Icebox ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 276: https://www.vlr.gg/183793/kr-esports-vs-100-thieves-champions-tour-2023-americas-league-w4
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Fracture ... 10 jogadores
#      📐 Aba expandida para 27493 linhas
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 277: https://www.vlr.gg/183794/evil-geniuses-vs-furia-champions-tour-2023-americas-league-w4
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 278: https://www.vlr.gg/183795/nrg-esports-vs-cloud9-champions-tour-2023-americas-league-w4
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
# /tmp/ipykernel_31043/1992354590.py:247: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dfs, ignore_index=True) if dfs else None
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 279: https://www.vlr.gg/183796/mibr-vs-sentinels-champions-tour-2023-americas-league-w4
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 280: https://www.vlr.gg/183797/leviat-n-vs-100-thieves-champions-tour-2023-americas-league-w4
#        [Mapa 0] Icebox ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 281: https://www.vlr.gg/183798/evil-geniuses-vs-loud-champions-tour-2023-americas-league-w4
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 282: https://www.vlr.gg/183799/cloud9-vs-furia-champions-tour-2023-americas-league-w4
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 283: https://www.vlr.gg/183800/nrg-esports-vs-kr-esports-champions-tour-2023-americas-league-w4
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 284: https://www.vlr.gg/183801/nrg-esports-vs-100-thieves-champions-tour-2023-americas-league-w5
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 285: https://www.vlr.gg/183802/mibr-vs-furia-champions-tour-2023-americas-league-w5
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 286: https://www.vlr.gg/183803/cloud9-vs-sentinels-champions-tour-2023-americas-league-w5
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 287: https://www.vlr.gg/183804/leviat-n-vs-evil-geniuses-champions-tour-2023-americas-league-w5
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 288: https://www.vlr.gg/183805/loud-vs-kr-esports-champions-tour-2023-americas-league-w5
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 289: https://www.vlr.gg/183807/evil-geniuses-vs-sentinels-champions-tour-2023-americas-league-w6
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 290: https://www.vlr.gg/183808/cloud9-vs-mibr-champions-tour-2023-americas-league-w6
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 291: https://www.vlr.gg/183809/loud-vs-100-thieves-champions-tour-2023-americas-league-w6
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 292: https://www.vlr.gg/183810/leviat-n-vs-kr-esports-champions-tour-2023-americas-league-w6
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 293: https://www.vlr.gg/183811/nrg-esports-vs-furia-champions-tour-2023-americas-league-w6
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Pearl ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 294: https://www.vlr.gg/183812/furia-vs-100-thieves-champions-tour-2023-americas-league-w7
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 295: https://www.vlr.gg/183813/evil-geniuses-vs-mibr-champions-tour-2023-americas-league-w7
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Fracture ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 296: https://www.vlr.gg/183814/kr-esports-vs-sentinels-champions-tour-2023-americas-league-w7
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 297: https://www.vlr.gg/183815/nrg-esports-vs-loud-champions-tour-2023-americas-league-w7
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 298: https://www.vlr.gg/183816/leviat-n-vs-cloud9-champions-tour-2023-americas-league-w7
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 299: https://www.vlr.gg/184032/sentinels-vs-furia-champions-tour-2023-americas-league-w8
#        [Mapa 0] Split ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 300: https://www.vlr.gg/184033/nrg-esports-vs-evil-geniuses-champions-tour-2023-americas-league-w8
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 301: https://www.vlr.gg/184034/cloud9-vs-kr-esports-champions-tour-2023-americas-league-w8
#        [Mapa 0] Lotus ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Split ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 302: https://www.vlr.gg/184035/leviat-n-vs-loud-champions-tour-2023-americas-league-w8
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 303: https://www.vlr.gg/184036/mibr-vs-100-thieves-champions-tour-2023-americas-league-w8
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 304: https://www.vlr.gg/189050/leviat-n-vs-furia-champions-tour-2023-americas-league-ur1
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Pearl ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 305: https://www.vlr.gg/189051/nrg-esports-vs-evil-geniuses-champions-tour-2023-americas-league-ur1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Split ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 306: https://www.vlr.gg/189052/loud-vs-furia-champions-tour-2023-americas-league-ubsf
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#      📐 Aba expandida para 28523 linhas
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 307: https://www.vlr.gg/189053/cloud9-vs-evil-geniuses-champions-tour-2023-americas-league-ubsf
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 308: https://www.vlr.gg/189056/cloud9-vs-leviat-n-champions-tour-2023-americas-league-lr1
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Ascent ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 309: https://www.vlr.gg/189057/furia-vs-nrg-esports-champions-tour-2023-americas-league-lr1
#        [Mapa 0] Bind ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Haven ... 10 jogadores
#      ✔ 30 linhas escritas na aba 'Stats'
#      ✔ 30 linhas salvas em 'vlr_stats2.csv'
#   → Linha 310: https://www.vlr.gg/189054/loud-vs-evil-geniuses-champions-tour-2023-americas-league-ubf
#        [Mapa 0] Fracture ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Bind ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 311: https://www.vlr.gg/189058/cloud9-vs-nrg-esports-champions-tour-2023-americas-league-lr2
#        [Mapa 0] Pearl ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Lotus ... 10 jogadores
#        [Mapa 3] Haven ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#   → Linha 312: https://www.vlr.gg/189059/evil-geniuses-vs-nrg-esports-champions-tour-2023-americas-league-lbf
#        [Mapa 0] Haven ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Ascent ... 10 jogadores
#        [Mapa 3] Lotus ... 10 jogadores
#        [Mapa 4] Split ... 10 jogadores
#      ✔ 50 linhas escritas na aba 'Stats'
#      ✔ 50 linhas salvas em 'vlr_stats2.csv'
#   → Linha 313: https://www.vlr.gg/189055/loud-vs-nrg-esports-champions-tour-2023-americas-league-gf
#        [Mapa 0] Ascent ... 10 jogadores
#        [All Maps] AllMaps ... 10 jogadores
#        [Mapa 2] Bind ... 10 jogadores
#        [Mapa 3] Fracture ... 10 jogadores
#      ✔ 40 linhas escritas na aba 'Stats'
#      ✔ 40 linhas salvas em 'vlr_stats2.csv'
#
# ✅ Coleta finalizada! Dados salvos em 'vlr_stats2.csv' e na planilha.

# %% [markdown]
# # COLETA DOS PLACARES DOS JOGOS

# %%
import re
import time
import os

import gspread
import pandas as pd
import requests
from bs4 import BeautifulSoup
from google.oauth2.service_account import Credentials

# ─────────────────────────────────────────────
#  CONFIGURAÇÃO
# ─────────────────────────────────────────────

CREDENTIALS_FILE = "teste-coleta-489718-87d9ed749c61.json"
SPREADSHEET_ID   = "1wAcPW4R9jIfi9fkgOO-sPhQGxJQJQxvAp2t5Ff0upMg"
ABA_URLS         = "Página1"
ABA_PLACAR       = "Placar"
OUTPUT_CSV       = "vlr_placar2.csv"
DELAY            = 2

SCOPES = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive",
]

# ─────────────────────────────────────────────
#  GOOGLE SHEETS
# ─────────────────────────────────────────────

def conectar_sheets():
    creds  = Credentials.from_service_account_file(CREDENTIALS_FILE, scopes=SCOPES)
    client = gspread.authorize(creds)
    return client.open_by_key(SPREADSHEET_ID)


def ler_urls_pendentes(sheet):
    aba     = sheet.worksheet(ABA_URLS)
    valores = aba.get_all_values()
    pendentes = []
    for i, row in enumerate(valores, start=1):
        if not row or not row[0].strip():
            continue
        url    = row[0].strip()
        status = row[2].strip().lower() if len(row) > 2 else ""
        if status not in ("ok", "erro"):
            pendentes.append((i, url))
    return aba, pendentes


def marcar_status(aba, linha, status):
    aba.update_cell(linha, 3, status)


def _expandir_aba(aba, linhas_necessarias):
    """Expande a aba automaticamente se o número de linhas for insuficiente."""
    props = aba.spreadsheet.fetch_sheet_metadata()
    for s in props["sheets"]:
        if s["properties"]["title"] == aba.title:
            atual = s["properties"]["gridProperties"]["rowCount"]
            if linhas_necessarias > atual:
                aba.add_rows(linhas_necessarias - atual + 1000)
                print(f"     📐 Aba expandida para {linhas_necessarias + 1000} linhas")
            break


def escrever_placar(sheet, df):
    try:
        aba = sheet.worksheet(ABA_PLACAR)
    except gspread.exceptions.WorksheetNotFound:
        aba = sheet.add_worksheet(title=ABA_PLACAR, rows=100, cols=10)

    existentes = aba.get_all_values()
    df_limpo   = df.fillna("")
    novas_rows = df_limpo.values.tolist()

    if not existentes:
        todas = [df_limpo.columns.tolist()] + novas_rows
        _expandir_aba(aba, len(todas))
        aba.update(values=todas, range_name="A1")
    else:
        proxima = len(existentes) + 1
        _expandir_aba(aba, proxima + len(novas_rows))
        aba.update(values=novas_rows, range_name=f"A{proxima}")

    print(f"     ✔ {len(df)} linhas escritas na aba '{ABA_PLACAR}'")


def salvar_csv(df, caminho):
    existe = os.path.isfile(caminho)
    df.to_csv(caminho, mode="a", index=False, header=not existe)
    print(f"     ✔ {len(df)} linhas salvas em '{caminho}'")


# ─────────────────────────────────────────────
#  HELPERS
# ─────────────────────────────────────────────

def extrair_times_da_pagina(soup):
    """Pega os nomes dos dois times do topo da página."""
    els = soup.select(".match-header-link-name")
    if len(els) >= 2:
        return els[0].get_text(strip=True), els[1].get_text(strip=True)
    return None, None


def get_map_name(block):
    """
    Retorna nome do mapa se for bloco individual (Bind, Haven...),
    ou None se for o bloco All Maps.
    """
    header = block.select_one(".vm-stats-game-header")
    if not header:
        return None
    text  = header.get_text(" ", strip=True)
    match = re.search(
        r'\b(Bind|Haven|Split|Ascent|Icebox|Breeze|Fracture|Pearl|Lotus|Sunset|Abyss|Corrode)\b',
        text, re.IGNORECASE,
    )
    return match.group(1).capitalize() if match else None


def bloco_tem_dados(block):
    """Retorna True se o bloco tiver linhas de jogadores preenchidas."""
    for row in block.select(".wf-table-inset tr"):
        cells = row.select("td")
        if cells and any(c.get_text(strip=True) for c in cells):
            return True
    return False


def extrair_score_bloco(block):
    """
    Extrai os dois scores totais do header de um bloco de mapa individual.
    Retorna (score_time1, score_time2).
    """
    header = block.select_one(".vm-stats-game-header")
    if not header:
        return None, None

    score_els = [
        el for el in header.select(".score")
        if "mod-t"  not in el.get("class", [])
        and "mod-ct" not in el.get("class", [])
    ]

    def to_int(el):
        try:
            return int(el.get_text(strip=True))
        except (ValueError, AttributeError):
            return None

    s1 = to_int(score_els[0]) if len(score_els) > 0 else None
    s2 = to_int(score_els[1]) if len(score_els) > 1 else None
    return s1, s2


# ─────────────────────────────────────────────
#  SCRAPING
# ─────────────────────────────────────────────

def scrape_placar(url):
    req_headers = {"User-Agent": "Mozilla/5.0"}
    response    = requests.get(url, headers=req_headers, timeout=15)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")

    time1, time2 = extrair_times_da_pagina(soup)
    if not time1 or not time2:
        print("     ⚠️  Não encontrou os times na página")
        return None

    all_blocks = soup.select(".vm-stats-game")
    if not all_blocks:
        return None

    rows = []
    for block in all_blocks:
        nome_mapa = get_map_name(block)

        if not nome_mapa or not bloco_tem_dados(block):
            continue

        s1, s2 = extrair_score_bloco(block)

        if s1 is not None and s2 is not None:
            vencedor = time1 if s1 > s2 else (time2 if s2 > s1 else "Empate")
        else:
            vencedor = None

        rows.append({
            "URL":      url,
            "Mapa":     nome_mapa,
            "Time1":    time1,
            "Score_T1": s1,
            "Time2":    time2,
            "Score_T2": s2,
            "Vencedor": vencedor,
        })

        print(f"       {nome_mapa}: {time1} {s1} x {s2} {time2}  → {vencedor}")

    if not rows:
        return None

    df_mapas = pd.DataFrame(rows)

    # Vencedor = quem ganhou mais mapas individuais
    mapas_t1 = (df_mapas["Vencedor"] == time1).sum()
    mapas_t2 = (df_mapas["Vencedor"] == time2).sum()

    if mapas_t1 > mapas_t2:
        venc_all = time1
    elif mapas_t2 > mapas_t1:
        venc_all = time2
    else:
        venc_all = "Empate"

    all_maps_row = pd.DataFrame([{
        "URL":      url,
        "Mapa":     "AllMaps",
        "Time1":    time1,
        "Mapas_T1": int(mapas_t1),
        "Score_T1": int(df_mapas["Score_T1"].sum()),
        "Time2":    time2,
        "Mapas_T2": int(mapas_t2),
        "Score_T2": int(df_mapas["Score_T2"].sum()),
        "Vencedor": venc_all,
    }])

    print(f"       AllMaps: {time1} {mapas_t1} x {mapas_t2} {time2}  → {venc_all}")

    df_mapas["Mapas_T1"] = None
    df_mapas["Mapas_T2"] = None

    cols = ["URL", "Mapa", "Time1", "Mapas_T1", "Score_T1",
            "Time2", "Mapas_T2", "Score_T2", "Vencedor"]
    df_mapas     = df_mapas[cols]
    all_maps_row = all_maps_row[cols]

    return pd.concat([df_mapas, all_maps_row], ignore_index=True)


# ─────────────────────────────────────────────
#  EXECUÇÃO PRINCIPAL
# ─────────────────────────────────────────────

def main():
    print("🔗 Conectando ao Google Sheets...")
    sheet = conectar_sheets()

    aba_urls, pendentes = ler_urls_pendentes(sheet)

    if not pendentes:
        print("✅ Nenhuma URL pendente.")
        return

    print(f"📋 {len(pendentes)} URL(s) pendente(s)\n")

    for linha, url in pendentes:
        print(f"  → Linha {linha}: {url}")
        try:
            df = scrape_placar(url)
            if df is not None and not df.empty:
                escrever_placar(sheet, df)
                salvar_csv(df, OUTPUT_CSV)
                marcar_status(aba_urls, linha, "ok")
            else:
                print("     ⚠️  Sem dados")
                marcar_status(aba_urls, linha, "erro")
        except Exception as e:
            print(f"     ❌ Erro: {e}")
            marcar_status(aba_urls, linha, "erro")

        time.sleep(DELAY)

    print(f"\n✅ Finalizado! Dados em '{OUTPUT_CSV}' e na aba '{ABA_PLACAR}'.")


if __name__ == "__main__":
    main()
# Out:
# 🔗 Conectando ao Google Sheets...
# 📋 312 URL(s) pendente(s)
#
#   → Linha 2: https://www.vlr.gg/596398/loud-vs-cloud9-vct-2026-americas-kickoff-ur1
#        Haven: LOUD 7 x 13 Cloud9  → Cloud9
#        Abyss: LOUD 11 x 13 Cloud9  → Cloud9
#        AllMaps: LOUD 0 x 2 Cloud9  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 3: https://www.vlr.gg/596399/envy-vs-evil-geniuses-vct-2026-americas-kickoff-ur1
#        Abyss: ENVY 9 x 13 Evil Geniuses  → Evil Geniuses
#        Corrode: ENVY 13 x 10 Evil Geniuses  → ENVY
#        Bind: ENVY 13 x 9 Evil Geniuses  → ENVY
#        AllMaps: ENVY 2 x 1 Evil Geniuses  → ENVY
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 4: https://www.vlr.gg/596400/kr-esports-vs-furia-vct-2026-americas-kickoff-ur1
#        Pearl: KRÜ Esports 13 x 10 FURIA  → KRÜ Esports
#        Breeze: KRÜ Esports 8 x 13 FURIA  → FURIA
#        Abyss: KRÜ Esports 5 x 13 FURIA  → FURIA
#        AllMaps: KRÜ Esports 1 x 2 FURIA  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 5: https://www.vlr.gg/596401/100-thieves-vs-leviat-n-vct-2026-americas-kickoff-ur1
#        Bind: 100 Thieves 13 x 9 LEVIATÁN  → 100 Thieves
#        Pearl: 100 Thieves 10 x 13 LEVIATÁN  → LEVIATÁN
#        Split: 100 Thieves 13 x 9 LEVIATÁN  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 1 LEVIATÁN  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 6: https://www.vlr.gg/596402/nrg-vs-cloud9-vct-2026-americas-kickoff-ur2
#        Pearl: NRG 13 x 2 Cloud9  → NRG
#        Breeze: NRG 13 x 9 Cloud9  → NRG
#        AllMaps: NRG 2 x 0 Cloud9  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 7: https://www.vlr.gg/596403/mibr-vs-envy-vct-2026-americas-kickoff-ur2
#        Abyss: MIBR 13 x 7 ENVY  → MIBR
#        Corrode: MIBR 13 x 11 ENVY  → MIBR
#        AllMaps: MIBR 2 x 0 ENVY  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 8: https://www.vlr.gg/596404/sentinels-vs-furia-vct-2026-americas-kickoff-ur2
#        Split: Sentinels 5 x 13 FURIA  → FURIA
#        Breeze: Sentinels 11 x 13 FURIA  → FURIA
#        AllMaps: Sentinels 0 x 2 FURIA  → FURIA
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 9: https://www.vlr.gg/596405/g2-esports-vs-100-thieves-vct-2026-americas-kickoff-ur2
#        Bind: G2 Esports 13 x 11 100 Thieves  → G2 Esports
#        Corrode: G2 Esports 3 x 13 100 Thieves  → 100 Thieves
#        Split: G2 Esports 13 x 8 100 Thieves  → G2 Esports
#        AllMaps: G2 Esports 2 x 1 100 Thieves  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 10: https://www.vlr.gg/596409/loud-vs-100-thieves-vct-2026-americas-kickoff-mr1
#        Breeze: LOUD 13 x 11 100 Thieves  → LOUD
#        Bind: LOUD 6 x 13 100 Thieves  → 100 Thieves
#        Pearl: LOUD 2 x 13 100 Thieves  → 100 Thieves
#        AllMaps: LOUD 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 11: https://www.vlr.gg/596410/evil-geniuses-vs-sentinels-vct-2026-americas-kickoff-mr1
#        Abyss: Evil Geniuses 8 x 13 Sentinels  → Sentinels
#        Pearl: Evil Geniuses 11 x 13 Sentinels  → Sentinels
#        AllMaps: Evil Geniuses 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 12: https://www.vlr.gg/596411/kr-esports-vs-envy-vct-2026-americas-kickoff-mr1
#        Abyss: KRÜ Esports 13 x 9 ENVY  → KRÜ Esports
#        Pearl: KRÜ Esports 5 x 13 ENVY  → ENVY
#        Breeze: KRÜ Esports 9 x 13 ENVY  → ENVY
#        AllMaps: KRÜ Esports 1 x 2 ENVY  → ENVY
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 13: https://www.vlr.gg/596412/leviat-n-vs-cloud9-vct-2026-americas-kickoff-mr1
#        Pearl: LEVIATÁN 3 x 13 Cloud9  → Cloud9
#        Split: LEVIATÁN 8 x 13 Cloud9  → Cloud9
#        AllMaps: LEVIATÁN 0 x 2 Cloud9  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 14: https://www.vlr.gg/596413/100-thieves-vs-sentinels-vct-2026-americas-kickoff-mr2
#        Corrode: 100 Thieves 13 x 11 Sentinels  → 100 Thieves
#        Split: 100 Thieves 16 x 14 Sentinels  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 Sentinels  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 15: https://www.vlr.gg/596414/envy-vs-cloud9-vct-2026-americas-kickoff-mr2
#        Pearl: ENVY 18 x 20 Cloud9  → Cloud9
#        Breeze: ENVY 13 x 8 Cloud9  → ENVY
#        Split: ENVY 11 x 13 Cloud9  → Cloud9
#        AllMaps: ENVY 1 x 2 Cloud9  → Cloud9
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 16: https://www.vlr.gg/596406/nrg-vs-mibr-vct-2026-americas-kickoff-ur3
#        Abyss: NRG 13 x 6 MIBR  → NRG
#        Split: NRG 11 x 13 MIBR  → MIBR
#        Breeze: NRG 8 x 13 MIBR  → MIBR
#        AllMaps: NRG 1 x 2 MIBR  → MIBR
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 17: https://www.vlr.gg/596407/furia-vs-g2-esports-vct-2026-americas-kickoff-ur3
#        Abyss: FURIA 13 x 7 G2 Esports  → FURIA
#        Bind: FURIA 6 x 13 G2 Esports  → G2 Esports
#        Split: FURIA 13 x 3 G2 Esports  → FURIA
#        AllMaps: FURIA 2 x 1 G2 Esports  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 18: https://www.vlr.gg/596419/loud-vs-evil-geniuses-vct-2026-americas-kickoff-lr1
#        Haven: LOUD 5 x 13 Evil Geniuses  → Evil Geniuses
#        Abyss: LOUD 12 x 14 Evil Geniuses  → Evil Geniuses
#        AllMaps: LOUD 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 19: https://www.vlr.gg/596420/kr-esports-vs-leviat-n-vct-2026-americas-kickoff-lr1
#        Bind: KRÜ Esports 4 x 13 LEVIATÁN  → LEVIATÁN
#        Split: KRÜ Esports 10 x 13 LEVIATÁN  → LEVIATÁN
#        AllMaps: KRÜ Esports 0 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 20: https://www.vlr.gg/596415/nrg-vs-100-thieves-vct-2026-americas-kickoff-mr3
#        Haven: NRG 13 x 9 100 Thieves  → NRG
#        Corrode: NRG 13 x 11 100 Thieves  → NRG
#        AllMaps: NRG 2 x 0 100 Thieves  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 21: https://www.vlr.gg/596416/g2-esports-vs-cloud9-vct-2026-americas-kickoff-mr3
#        Corrode: G2 Esports 13 x 11 Cloud9  → G2 Esports
#        Bind: G2 Esports 13 x 9 Cloud9  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 Cloud9  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 22: https://www.vlr.gg/596421/envy-vs-evil-geniuses-vct-2026-americas-kickoff-lr2
#        Pearl: ENVY 14 x 16 Evil Geniuses  → Evil Geniuses
#        Corrode: ENVY 5 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: ENVY 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 23: https://www.vlr.gg/596422/sentinels-vs-leviat-n-vct-2026-americas-kickoff-lr2
#        Corrode: Sentinels 10 x 13 LEVIATÁN  → LEVIATÁN
#        Bind: Sentinels 12 x 14 LEVIATÁN  → LEVIATÁN
#        AllMaps: Sentinels 0 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 24: https://www.vlr.gg/596417/nrg-vs-g2-esports-vct-2026-americas-kickoff-mr4
#        Pearl: NRG 3 x 13 G2 Esports  → G2 Esports
#        Split: NRG 8 x 13 G2 Esports  → G2 Esports
#        AllMaps: NRG 0 x 2 G2 Esports  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 25: https://www.vlr.gg/596423/100-thieves-vs-evil-geniuses-vct-2026-americas-kickoff-lr3
#        Haven: 100 Thieves 13 x 11 Evil Geniuses  → 100 Thieves
#        Bind: 100 Thieves 15 x 13 Evil Geniuses  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 Evil Geniuses  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 26: https://www.vlr.gg/596424/cloud9-vs-leviat-n-vct-2026-americas-kickoff-lr3
#        Bind: Cloud9 13 x 5 LEVIATÁN  → Cloud9
#        Breeze: Cloud9 13 x 7 LEVIATÁN  → Cloud9
#        AllMaps: Cloud9 2 x 0 LEVIATÁN  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 27: https://www.vlr.gg/596408/mibr-vs-furia-vct-2026-americas-kickoff-ubf
#        Bind: MIBR 13 x 8 FURIA  → MIBR
#        Abyss: MIBR 8 x 13 FURIA  → FURIA
#        Haven: MIBR 11 x 13 FURIA  → FURIA
#        Breeze: MIBR 13 x 2 FURIA  → MIBR
#        Split: MIBR 8 x 13 FURIA  → FURIA
#        AllMaps: MIBR 2 x 3 FURIA  → FURIA
#      ✔ 6 linhas escritas na aba 'Placar'
#      ✔ 6 linhas salvas em 'vlr_placar2.csv'
#   → Linha 28: https://www.vlr.gg/596425/100-thieves-vs-cloud9-vct-2026-americas-kickoff-lr4
#        Pearl: 100 Thieves 14 x 12 Cloud9  → 100 Thieves
#        Split: 100 Thieves 11 x 13 Cloud9  → Cloud9
#        Abyss: 100 Thieves 13 x 2 Cloud9  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 1 Cloud9  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 29: https://www.vlr.gg/596418/mibr-vs-g2-esports-vct-2026-americas-kickoff-mbf
#        Breeze: MIBR 6 x 13 G2 Esports  → G2 Esports
#        Haven: MIBR 4 x 13 G2 Esports  → G2 Esports
#        Corrode: MIBR 7 x 13 G2 Esports  → G2 Esports
#        AllMaps: MIBR 0 x 3 G2 Esports  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 30: https://www.vlr.gg/596426/nrg-vs-100-thieves-vct-2026-americas-kickoff-lr5
#        Pearl: NRG 13 x 3 100 Thieves  → NRG
#        Abyss: NRG 13 x 8 100 Thieves  → NRG
#        AllMaps: NRG 2 x 0 100 Thieves  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 31: https://www.vlr.gg/596427/mibr-vs-nrg-vct-2026-americas-kickoff-lbf
#        Bind: MIBR 13 x 9 NRG  → MIBR
#        Corrode: MIBR 13 x 5 NRG  → MIBR
#        Split: MIBR 10 x 13 NRG  → NRG
#        Abyss: MIBR 4 x 13 NRG  → NRG
#        Haven: MIBR 5 x 13 NRG  → NRG
#        AllMaps: MIBR 2 x 3 NRG  → NRG
#      ✔ 6 linhas escritas na aba 'Placar'
#      ✔ 6 linhas salvas em 'vlr_placar2.csv'
#   → Linha 32: https://www.vlr.gg/645475/g2-esports-vs-mibr-vct-2026-americas-stage-1-w1
#        Lotus: G2 Esports 8 x 13 MIBR  → MIBR
#        Split: G2 Esports 14 x 16 MIBR  → MIBR
#        AllMaps: G2 Esports 0 x 2 MIBR  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 33: https://www.vlr.gg/645477/envy-vs-loud-vct-2026-americas-stage-1-w1
#        Lotus: ENVY 13 x 9 LOUD  → ENVY
#        Pearl: ENVY 11 x 13 LOUD  → LOUD
#        Breeze: ENVY 8 x 13 LOUD  → LOUD
#        AllMaps: ENVY 1 x 2 LOUD  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 34: https://www.vlr.gg/645478/cloud9-vs-leviat-n-vct-2026-americas-stage-1-w1
#        Pearl: Cloud9 6 x 13 LEVIATÁN  → LEVIATÁN
#        Haven: Cloud9 5 x 13 LEVIATÁN  → LEVIATÁN
#        AllMaps: Cloud9 0 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 35: https://www.vlr.gg/645480/cloud9-vs-envy-vct-2026-americas-stage-1-w2
#        Split: Cloud9 13 x 11 ENVY  → Cloud9
#        Pearl: Cloud9 5 x 13 ENVY  → ENVY
#        Haven: Cloud9 9 x 13 ENVY  → ENVY
#        AllMaps: Cloud9 1 x 2 ENVY  → ENVY
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 36: https://www.vlr.gg/645482/g2-esports-vs-leviat-n-vct-2026-americas-stage-1-w2
#        Breeze: G2 Esports 13 x 6 LEVIATÁN  → G2 Esports
#        Split: G2 Esports 11 x 13 LEVIATÁN  → LEVIATÁN
#        Bind: G2 Esports 12 x 14 LEVIATÁN  → LEVIATÁN
#        AllMaps: G2 Esports 1 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 37: https://www.vlr.gg/645483/mibr-vs-loud-vct-2026-americas-stage-1-w2
#        Haven: MIBR 13 x 10 LOUD  → MIBR
#        Split: MIBR 13 x 4 LOUD  → MIBR
#        AllMaps: MIBR 2 x 0 LOUD  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 38: https://www.vlr.gg/645486/leviat-n-vs-envy-vct-2026-americas-stage-1-w3
#        Bind: LEVIATÁN 13 x 4 ENVY  → LEVIATÁN
#        Fracture: LEVIATÁN 13 x 4 ENVY  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 0 ENVY  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 39: https://www.vlr.gg/645487/g2-esports-vs-loud-vct-2026-americas-stage-1-w3
#        Haven: G2 Esports 13 x 9 LOUD  → G2 Esports
#        Pearl: G2 Esports 13 x 10 LOUD  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 LOUD  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 40: https://www.vlr.gg/645491/mibr-vs-cloud9-vct-2026-americas-stage-1-w3
#        Breeze: MIBR 12 x 14 Cloud9  → Cloud9
#        Split: MIBR 12 x 14 Cloud9  → Cloud9
#        AllMaps: MIBR 0 x 2 Cloud9  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 41: https://www.vlr.gg/645493/leviat-n-vs-mibr-vct-2026-americas-stage-1-w4
#        Breeze: LEVIATÁN 10 x 13 MIBR  → MIBR
#        Haven: LEVIATÁN 10 x 13 MIBR  → MIBR
#        AllMaps: LEVIATÁN 0 x 2 MIBR  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 42: https://www.vlr.gg/645496/loud-vs-cloud9-vct-2026-americas-stage-1-w4
#        Lotus: LOUD 13 x 1 Cloud9  → LOUD
#        Split: LOUD 8 x 13 Cloud9  → Cloud9
#        Breeze: LOUD 13 x 11 Cloud9  → LOUD
#        AllMaps: LOUD 2 x 1 Cloud9  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 43: https://www.vlr.gg/645497/g2-esports-vs-envy-vct-2026-americas-stage-1-w4
#        Haven: G2 Esports 13 x 4 ENVY  → G2 Esports
#        Lotus: G2 Esports 13 x 6 ENVY  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 ENVY  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 44: https://www.vlr.gg/645500/g2-esports-vs-cloud9-vct-2026-americas-stage-1-w5
#        Lotus: G2 Esports 13 x 6 Cloud9  → G2 Esports
#        Split: G2 Esports 13 x 9 Cloud9  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 Cloud9  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 45: https://www.vlr.gg/645501/envy-vs-mibr-vct-2026-americas-stage-1-w5
#        Haven: ENVY 13 x 1 MIBR  → ENVY
#        Bind: ENVY 13 x 3 MIBR  → ENVY
#        AllMaps: ENVY 2 x 0 MIBR  → ENVY
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 46: https://www.vlr.gg/645502/loud-vs-leviat-n-vct-2026-americas-stage-1-w5
#        Bind: LOUD 3 x 13 LEVIATÁN  → LEVIATÁN
#        Breeze: LOUD 14 x 12 LEVIATÁN  → LOUD
#        Haven: LOUD 13 x 10 LEVIATÁN  → LOUD
#        AllMaps: LOUD 2 x 1 LEVIATÁN  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 47: https://www.vlr.gg/645474/sentinels-vs-kr-esports-vct-2026-americas-stage-1-w1
#        Lotus: Sentinels 8 x 13 KRÜ Esports  → KRÜ Esports
#        Breeze: Sentinels 9 x 13 KRÜ Esports  → KRÜ Esports
#        AllMaps: Sentinels 0 x 2 KRÜ Esports  → KRÜ Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 48: https://www.vlr.gg/645476/100-thieves-vs-evil-geniuses-vct-2026-americas-stage-1-w1
#        Haven: 100 Thieves 13 x 8 Evil Geniuses  → 100 Thieves
#        Breeze: 100 Thieves 13 x 4 Evil Geniuses  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 Evil Geniuses  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 49: https://www.vlr.gg/645479/furia-vs-nrg-vct-2026-americas-stage-1-w1
#        Pearl: FURIA 13 x 7 NRG  → FURIA
#        Split: FURIA 13 x 10 NRG  → FURIA
#        AllMaps: FURIA 2 x 0 NRG  → FURIA
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 50: https://www.vlr.gg/645481/furia-vs-evil-geniuses-vct-2026-americas-stage-1-w2
#        Haven: FURIA 12 x 14 Evil Geniuses  → Evil Geniuses
#        Pearl: FURIA 13 x 5 Evil Geniuses  → FURIA
#        Lotus: FURIA 13 x 10 Evil Geniuses  → FURIA
#        AllMaps: FURIA 2 x 1 Evil Geniuses  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 51: https://www.vlr.gg/645484/nrg-vs-kr-esports-vct-2026-americas-stage-1-w2
#        Lotus: NRG 10 x 13 KRÜ Esports  → KRÜ Esports
#        Split: NRG 8 x 13 KRÜ Esports  → KRÜ Esports
#        AllMaps: NRG 0 x 2 KRÜ Esports  → KRÜ Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 52: https://www.vlr.gg/645485/100-thieves-vs-sentinels-vct-2026-americas-stage-1-w2
#        Haven: 100 Thieves 10 x 13 Sentinels  → Sentinels
#        Split: 100 Thieves 17 x 19 Sentinels  → Sentinels
#        AllMaps: 100 Thieves 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 53: https://www.vlr.gg/645488/furia-vs-kr-esports-vct-2026-americas-stage-1-w3
#        Lotus: FURIA 4 x 13 KRÜ Esports  → KRÜ Esports
#        Haven: FURIA 10 x 13 KRÜ Esports  → KRÜ Esports
#        AllMaps: FURIA 0 x 2 KRÜ Esports  → KRÜ Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 54: https://www.vlr.gg/645489/nrg-vs-100-thieves-vct-2026-americas-stage-1-w3
#        Pearl: NRG 9 x 13 100 Thieves  → 100 Thieves
#        Lotus: NRG 13 x 10 100 Thieves  → NRG
#        Breeze: NRG 13 x 2 100 Thieves  → NRG
#        AllMaps: NRG 2 x 1 100 Thieves  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 55: https://www.vlr.gg/645490/evil-geniuses-vs-sentinels-vct-2026-americas-stage-1-w3
#        Haven: Evil Geniuses 7 x 13 Sentinels  → Sentinels
#        Bind: Evil Geniuses 11 x 13 Sentinels  → Sentinels
#        AllMaps: Evil Geniuses 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 56: https://www.vlr.gg/645492/evil-geniuses-vs-nrg-vct-2026-americas-stage-1-w4
#        Fracture: Evil Geniuses 8 x 13 NRG  → NRG
#        Pearl: Evil Geniuses 9 x 13 NRG  → NRG
#        AllMaps: Evil Geniuses 0 x 2 NRG  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 57: https://www.vlr.gg/645494/kr-esports-vs-100-thieves-vct-2026-americas-stage-1-w4
#        Bind: KRÜ Esports 4 x 13 100 Thieves  → 100 Thieves
#        Haven: KRÜ Esports 13 x 10 100 Thieves  → KRÜ Esports
#        Split: KRÜ Esports 6 x 13 100 Thieves  → 100 Thieves
#        AllMaps: KRÜ Esports 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 58: https://www.vlr.gg/645495/furia-vs-sentinels-vct-2026-americas-stage-1-w4
#        Split: FURIA 13 x 4 Sentinels  → FURIA
#        Breeze: FURIA 7 x 13 Sentinels  → Sentinels
#        Haven: FURIA 13 x 7 Sentinels  → FURIA
#        AllMaps: FURIA 2 x 1 Sentinels  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 59: https://www.vlr.gg/645498/kr-esports-vs-evil-geniuses-vct-2026-americas-stage-1-w5
#        Haven: KRÜ Esports 11 x 13 Evil Geniuses  → Evil Geniuses
#        Lotus: KRÜ Esports 13 x 11 Evil Geniuses  → KRÜ Esports
#        Bind: KRÜ Esports 13 x 6 Evil Geniuses  → KRÜ Esports
#        AllMaps: KRÜ Esports 2 x 1 Evil Geniuses  → KRÜ Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 60: https://www.vlr.gg/645503/sentinels-vs-nrg-vct-2026-americas-stage-1-w5
#        Fracture: Sentinels 11 x 13 NRG  → NRG
#        Breeze: Sentinels 13 x 11 NRG  → Sentinels
#        Lotus: Sentinels 10 x 13 NRG  → NRG
#        AllMaps: Sentinels 1 x 2 NRG  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 61: https://www.vlr.gg/645499/furia-vs-100-thieves-vct-2026-americas-stage-1-w5
#        Pearl: FURIA 13 x 9 100 Thieves  → FURIA
#        Haven: FURIA 8 x 13 100 Thieves  → 100 Thieves
#        Breeze: FURIA 6 x 13 100 Thieves  → 100 Thieves
#        AllMaps: FURIA 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 62: https://www.vlr.gg/530902/leviat-n-vs-cloud9-vct-2025-americas-stage-2-ur1
#        Corrode: LEVIATÁN 10 x 13 Cloud9  → Cloud9
#        Haven: LEVIATÁN 13 x 10 Cloud9  → LEVIATÁN
#        Lotus: LEVIATÁN 11 x 13 Cloud9  → Cloud9
#        AllMaps: LEVIATÁN 1 x 2 Cloud9  → Cloud9
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 63: https://www.vlr.gg/530906/sentinels-vs-cloud9-vct-2025-americas-stage-2-ubsf
#        Corrode: Sentinels 13 x 10 Cloud9  → Sentinels
#        Icebox: Sentinels 9 x 13 Cloud9  → Cloud9
#        Lotus: Sentinels 13 x 10 Cloud9  → Sentinels
#        AllMaps: Sentinels 2 x 1 Cloud9  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 64: https://www.vlr.gg/530903/g2-esports-vs-100-thieves-vct-2025-americas-stage-2-ur1
#        Sunset: G2 Esports 13 x 4 100 Thieves  → G2 Esports
#        Haven: G2 Esports 13 x 5 100 Thieves  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 100 Thieves  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 65: https://www.vlr.gg/530907/nrg-vs-g2-esports-vct-2025-americas-stage-2-ubsf
#        Corrode: NRG 13 x 10 G2 Esports  → NRG
#        Sunset: NRG 11 x 13 G2 Esports  → G2 Esports
#        Bind: NRG 7 x 13 G2 Esports  → G2 Esports
#        AllMaps: NRG 1 x 2 G2 Esports  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 66: https://www.vlr.gg/530910/sentinels-vs-g2-esports-vct-2025-americas-stage-2-ubf
#        Bind: Sentinels 8 x 13 G2 Esports  → G2 Esports
#        Sunset: Sentinels 9 x 13 G2 Esports  → G2 Esports
#        AllMaps: Sentinels 0 x 2 G2 Esports  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 67: https://www.vlr.gg/530913/g2-esports-vs-nrg-vct-2025-americas-stage-2-gf
#        Bind: G2 Esports 13 x 11 NRG  → G2 Esports
#        Lotus: G2 Esports 13 x 8 NRG  → G2 Esports
#        Ascent: G2 Esports 13 x 10 NRG  → G2 Esports
#        AllMaps: G2 Esports 3 x 0 NRG  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 68: https://www.vlr.gg/530904/leviat-n-vs-kr-esports-vct-2025-americas-stage-2-lr1
#        Lotus: LEVIATÁN 14 x 12 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#        Sunset: LEVIATÁN 6 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Haven: LEVIATÁN 13 x 8 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 1 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 69: https://www.vlr.gg/530905/100-thieves-vs-evil-geniuses-vct-2025-americas-stage-2-lr1
#        Bind: 100 Thieves 13 x 4 Evil Geniuses  → 100 Thieves
#        Corrode: 100 Thieves 14 x 12 Evil Geniuses  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 Evil Geniuses  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 70: https://www.vlr.gg/530908/nrg-vs-leviat-n-vct-2025-americas-stage-2-lr2
#        Ascent: NRG 13 x 2 LEVIATÁN  → NRG
#        Icebox: NRG 13 x 2 LEVIATÁN  → NRG
#        AllMaps: NRG 2 x 0 LEVIATÁN  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 71: https://www.vlr.gg/530909/cloud9-vs-100-thieves-vct-2025-americas-stage-2-lr2
#        Haven: Cloud9 13 x 9 100 Thieves  → Cloud9
#        Icebox: Cloud9 14 x 12 100 Thieves  → Cloud9
#        AllMaps: Cloud9 2 x 0 100 Thieves  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 72: https://www.vlr.gg/530911/nrg-vs-cloud9-vct-2025-americas-stage-2-lr3
#        Corrode: NRG 13 x 2 Cloud9  → NRG
#        Lotus: NRG 13 x 10 Cloud9  → NRG
#        Haven: NRG 10 x 13 Cloud9  → Cloud9
#        AllMaps: NRG 2 x 1 Cloud9  → NRG
#      📐 Aba expandida para 2310 linhas
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 73: https://www.vlr.gg/530912/sentinels-vs-nrg-vct-2025-americas-stage-2-lbf
#        Lotus: Sentinels 4 x 13 NRG  → NRG
#        Icebox: Sentinels 11 x 13 NRG  → NRG
#        Sunset: Sentinels 13 x 10 NRG  → Sentinels
#        Corrode: Sentinels 8 x 13 NRG  → NRG
#        AllMaps: Sentinels 1 x 3 NRG  → NRG
#      ✔ 5 linhas escritas na aba 'Placar'
#      ✔ 5 linhas salvas em 'vlr_placar2.csv'
#   → Linha 74: https://www.vlr.gg/509801/cloud9-vs-furia-vct-2025-americas-stage-2-w1
#        Haven: Cloud9 13 x 5 FURIA  → Cloud9
#        Bind: Cloud9 13 x 4 FURIA  → Cloud9
#        AllMaps: Cloud9 2 x 0 FURIA  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 75: https://www.vlr.gg/509803/evil-geniuses-vs-2game-esports-vct-2025-americas-stage-2-w1
#        Sunset: Evil Geniuses 7 x 13 2Game Esports  → 2Game Esports
#        Lotus: Evil Geniuses 13 x 11 2Game Esports  → Evil Geniuses
#        Ascent: Evil Geniuses 13 x 9 2Game Esports  → Evil Geniuses
#        AllMaps: Evil Geniuses 2 x 1 2Game Esports  → Evil Geniuses
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 76: https://www.vlr.gg/509806/sentinels-vs-g2-esports-vct-2025-americas-stage-2-w1
#        Corrode: Sentinels 13 x 8 G2 Esports  → Sentinels
#        Ascent: Sentinels 6 x 13 G2 Esports  → G2 Esports
#        Lotus: Sentinels 14 x 12 G2 Esports  → Sentinels
#        AllMaps: Sentinels 2 x 1 G2 Esports  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 77: https://www.vlr.gg/509807/2game-esports-vs-g2-esports-vct-2025-americas-stage-2-w2
#        Ascent: 2Game Esports 8 x 13 G2 Esports  → G2 Esports
#        Haven: 2Game Esports 5 x 13 G2 Esports  → G2 Esports
#        AllMaps: 2Game Esports 0 x 2 G2 Esports  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 78: https://www.vlr.gg/509811/cloud9-vs-evil-geniuses-vct-2025-americas-stage-2-w2
#        Lotus: Cloud9 13 x 7 Evil Geniuses  → Cloud9
#        Haven: Cloud9 13 x 10 Evil Geniuses  → Cloud9
#        AllMaps: Cloud9 2 x 0 Evil Geniuses  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 79: https://www.vlr.gg/509808/furia-vs-sentinels-vct-2025-americas-stage-2-w2
#        Sunset: FURIA 4 x 13 Sentinels  → Sentinels
#        Icebox: FURIA 0 x 13 Sentinels  → Sentinels
#        AllMaps: FURIA 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 80: https://www.vlr.gg/509813/2game-esports-vs-furia-vct-2025-americas-stage-2-w3
#        Corrode: 2Game Esports 12 x 14 FURIA  → FURIA
#        Sunset: 2Game Esports 13 x 3 FURIA  → 2Game Esports
#        Ascent: 2Game Esports 13 x 2 FURIA  → 2Game Esports
#        AllMaps: 2Game Esports 2 x 1 FURIA  → 2Game Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 81: https://www.vlr.gg/509815/sentinels-vs-cloud9-vct-2025-americas-stage-2-w3
#        Lotus: Sentinels 13 x 5 Cloud9  → Sentinels
#        Haven: Sentinels 13 x 9 Cloud9  → Sentinels
#        AllMaps: Sentinels 2 x 0 Cloud9  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 82: https://www.vlr.gg/509817/g2-esports-vs-evil-geniuses-vct-2025-americas-stage-2-w3
#        Corrode: G2 Esports 11 x 13 Evil Geniuses  → Evil Geniuses
#        Haven: G2 Esports 13 x 4 Evil Geniuses  → G2 Esports
#        Ascent: G2 Esports 13 x 4 Evil Geniuses  → G2 Esports
#        AllMaps: G2 Esports 2 x 1 Evil Geniuses  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 83: https://www.vlr.gg/509819/cloud9-vs-2game-esports-vct-2025-americas-stage-2-w4
#        Bind: Cloud9 13 x 1 2Game Esports  → Cloud9
#        Lotus: Cloud9 13 x 7 2Game Esports  → Cloud9
#        AllMaps: Cloud9 2 x 0 2Game Esports  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 84: https://www.vlr.gg/509821/sentinels-vs-evil-geniuses-vct-2025-americas-stage-2-w4
#        Lotus: Sentinels 13 x 8 Evil Geniuses  → Sentinels
#        Corrode: Sentinels 13 x 4 Evil Geniuses  → Sentinels
#        AllMaps: Sentinels 2 x 0 Evil Geniuses  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 85: https://www.vlr.gg/509823/furia-vs-g2-esports-vct-2025-americas-stage-2-w4
#        Corrode: FURIA 2 x 13 G2 Esports  → G2 Esports
#        Ascent: FURIA 5 x 13 G2 Esports  → G2 Esports
#        AllMaps: FURIA 0 x 2 G2 Esports  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 86: https://www.vlr.gg/509827/furia-vs-evil-geniuses-vct-2025-americas-stage-2-w5
#        Corrode: FURIA 6 x 13 Evil Geniuses  → Evil Geniuses
#        Ascent: FURIA 9 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: FURIA 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 87: https://www.vlr.gg/509829/2game-esports-vs-sentinels-vct-2025-americas-stage-2-w5
#        Sunset: 2Game Esports 13 x 9 Sentinels  → 2Game Esports
#        Lotus: 2Game Esports 4 x 13 Sentinels  → Sentinels
#        Haven: 2Game Esports 4 x 13 Sentinels  → Sentinels
#        AllMaps: 2Game Esports 1 x 2 Sentinels  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 88: https://www.vlr.gg/509830/g2-esports-vs-cloud9-vct-2025-americas-stage-2-w5
#        Ascent: G2 Esports 13 x 8 Cloud9  → G2 Esports
#        Lotus: G2 Esports 13 x 9 Cloud9  → G2 Esports
#        AllMaps: G2 Esports 2 x 0 Cloud9  → G2 Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 89: https://www.vlr.gg/509831/mibr-vs-loud-vct-2025-americas-stage-2-w5
#        Icebox: MIBR 13 x 11 LOUD  → MIBR
#        Sunset: MIBR 13 x 10 LOUD  → MIBR
#        AllMaps: MIBR 2 x 0 LOUD  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 90: https://www.vlr.gg/509826/100-thieves-vs-leviat-n-vct-2025-americas-stage-2-w5
#        Haven: 100 Thieves 13 x 10 LEVIATÁN  → 100 Thieves
#        Sunset: 100 Thieves 10 x 13 LEVIATÁN  → LEVIATÁN
#        Lotus: 100 Thieves 2 x 13 LEVIATÁN  → LEVIATÁN
#        AllMaps: 100 Thieves 1 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 91: https://www.vlr.gg/509825/kr-esports-vs-nrg-vct-2025-americas-stage-2-w5
#        Sunset: VISA KRÜ(KRÜ Esports) 13 x 6 NRG  → VISA KRÜ(KRÜ Esports)
#        Lotus: VISA KRÜ(KRÜ Esports) 7 x 13 NRG  → NRG
#        Haven: VISA KRÜ(KRÜ Esports) 5 x 13 NRG  → NRG
#        AllMaps: VISA KRÜ(KRÜ Esports) 1 x 2 NRG  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 92: https://www.vlr.gg/509824/loud-vs-100-thieves-vct-2025-americas-stage-2-w4
#        Sunset: LOUD 13 x 2 100 Thieves  → LOUD
#        Bind: LOUD 7 x 13 100 Thieves  → 100 Thieves
#        Lotus: LOUD 12 x 14 100 Thieves  → 100 Thieves
#        AllMaps: LOUD 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 93: https://www.vlr.gg/509822/leviat-n-vs-kr-esports-vct-2025-americas-stage-2-w4
#        Bind: LEVIATÁN 6 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Haven: LEVIATÁN 13 x 10 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#        Ascent: LEVIATÁN 13 x 4 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 1 VISA KRÜ(KRÜ Esports)  → LEVIATÁN
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 94: https://www.vlr.gg/509820/mibr-vs-nrg-vct-2025-americas-stage-2-w4
#        Lotus: MIBR 13 x 15 NRG  → NRG
#        Bind: MIBR 10 x 13 NRG  → NRG
#        AllMaps: MIBR 0 x 2 NRG  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 95: https://www.vlr.gg/509818/loud-vs-kr-esports-vct-2025-americas-stage-2-w3
#        Haven: LOUD 7 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Bind: LOUD 13 x 9 VISA KRÜ(KRÜ Esports)  → LOUD
#        Ascent: LOUD 4 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        AllMaps: LOUD 1 x 2 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 96: https://www.vlr.gg/509816/mibr-vs-100-thieves-vct-2025-americas-stage-2-w3
#        Icebox: MIBR 13 x 10 100 Thieves  → MIBR
#        Bind: MIBR 14 x 12 100 Thieves  → MIBR
#        AllMaps: MIBR 2 x 0 100 Thieves  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 97: https://www.vlr.gg/509814/leviat-n-vs-nrg-vct-2025-americas-stage-2-w3
#        Lotus: LEVIATÁN 7 x 13 NRG  → NRG
#        Haven: LEVIATÁN 14 x 12 NRG  → LEVIATÁN
#        Icebox: LEVIATÁN 11 x 13 NRG  → NRG
#        AllMaps: LEVIATÁN 1 x 2 NRG  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 98: https://www.vlr.gg/509812/mibr-vs-leviat-n-vct-2025-americas-stage-2-w2
#        Lotus: MIBR 8 x 13 LEVIATÁN  → LEVIATÁN
#        Sunset: MIBR 3 x 13 LEVIATÁN  → LEVIATÁN
#        AllMaps: MIBR 0 x 2 LEVIATÁN  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 99: https://www.vlr.gg/509810/nrg-vs-loud-vct-2025-americas-stage-2-w2
#        Haven: NRG 13 x 4 LOUD  → NRG
#        Corrode: NRG 13 x 9 LOUD  → NRG
#        AllMaps: NRG 2 x 0 LOUD  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 100: https://www.vlr.gg/509809/100-thieves-vs-kr-esports-vct-2025-americas-stage-2-w2
#        Corrode: 100 Thieves 13 x 4 VISA KRÜ(KRÜ Esports)  → 100 Thieves
#        Bind: 100 Thieves 13 x 5 VISA KRÜ(KRÜ Esports)  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 VISA KRÜ(KRÜ Esports)  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 101: https://www.vlr.gg/509805/100-thieves-vs-nrg-vct-2025-americas-stage-2-w1
#        Bind: 100 Thieves 13 x 10 NRG  → 100 Thieves
#        Sunset: 100 Thieves 13 x 4 NRG  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 NRG  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 102: https://www.vlr.gg/509804/mibr-vs-kr-esports-vct-2025-americas-stage-2-w1
#        Corrode: MIBR 13 x 9 VISA KRÜ(KRÜ Esports)  → MIBR
#        Ascent: MIBR 1 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Haven: MIBR 9 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        AllMaps: MIBR 1 x 2 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 103: https://www.vlr.gg/509802/leviat-n-vs-loud-vct-2025-americas-stage-2-w1
#        Bind: LEVIATÁN 13 x 10 LOUD  → LEVIATÁN
#        Ascent: LEVIATÁN 10 x 13 LOUD  → LOUD
#        Icebox: LEVIATÁN 11 x 13 LOUD  → LOUD
#        AllMaps: LEVIATÁN 1 x 2 LOUD  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 104: https://www.vlr.gg/475897/mibr-vs-100-thieves-champions-tour-2025-americas-stage-1-ubr1
#        Split: MIBR 13 x 10 100 Thieves  → MIBR
#        Icebox: MIBR 13 x 4 100 Thieves  → MIBR
#        AllMaps: MIBR 2 x 0 100 Thieves  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 105: https://www.vlr.gg/475899/kr-esports-vs-mibr-champions-tour-2025-americas-stage-1-ubsf
#        Lotus: VISA KRÜ(KRÜ Esports) 8 x 13 MIBR  → MIBR
#        Icebox: VISA KRÜ(KRÜ Esports) 5 x 13 MIBR  → MIBR
#        AllMaps: VISA KRÜ(KRÜ Esports) 0 x 2 MIBR  → MIBR
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 106: https://www.vlr.gg/475901/mibr-vs-sentinels-champions-tour-2025-americas-stage-1-ubf
#        Lotus: MIBR 7 x 13 Sentinels  → Sentinels
#        Split: MIBR 11 x 13 Sentinels  → Sentinels
#        AllMaps: MIBR 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 107: https://www.vlr.gg/475902/sentinels-vs-g2-esports-champions-tour-2025-americas-stage-1-gf
#        Haven: Sentinels 9 x 13 G2 Esports  → G2 Esports
#        Split: Sentinels 9 x 13 G2 Esports  → G2 Esports
#        Pearl: Sentinels 13 x 10 G2 Esports  → Sentinels
#        Ascent: Sentinels 10 x 13 G2 Esports  → G2 Esports
#        AllMaps: Sentinels 1 x 3 G2 Esports  → G2 Esports
#      ✔ 5 linhas escritas na aba 'Placar'
#      ✔ 5 linhas salvas em 'vlr_placar2.csv'
#   → Linha 108: https://www.vlr.gg/475898/sentinels-vs-cloud9-champions-tour-2025-americas-stage-1-ubr1
#        Ascent: Sentinels 13 x 9 Cloud9  → Sentinels
#        Pearl: Sentinels 13 x 9 Cloud9  → Sentinels
#        AllMaps: Sentinels 2 x 0 Cloud9  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 109: https://www.vlr.gg/475900/g2-esports-vs-sentinels-champions-tour-2025-americas-stage-1-ubsf
#        Split: G2 Esports 13 x 5 Sentinels  → G2 Esports
#        Icebox: G2 Esports 11 x 13 Sentinels  → Sentinels
#        Ascent: G2 Esports 11 x 13 Sentinels  → Sentinels
#        AllMaps: G2 Esports 1 x 2 Sentinels  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 110: https://www.vlr.gg/475903/100-thieves-vs-nrg-esports-champions-tour-2025-americas-stage-1-lr1
#        Fracture: 100 Thieves 13 x 5 NRG  → 100 Thieves
#        Haven: 100 Thieves 13 x 11 NRG  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 NRG  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 111: https://www.vlr.gg/475904/cloud9-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr1
#        Fracture: Cloud9 9 x 13 Evil Geniuses  → Evil Geniuses
#        Icebox: Cloud9 13 x 15 Evil Geniuses  → Evil Geniuses
#        AllMaps: Cloud9 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 112: https://www.vlr.gg/475905/g2-esports-vs-100-thieves-champions-tour-2025-americas-stage-1-lr2
#        Haven: G2 Esports 13 x 4 100 Thieves  → G2 Esports
#        Split: G2 Esports 12 x 14 100 Thieves  → 100 Thieves
#        Pearl: G2 Esports 16 x 14 100 Thieves  → G2 Esports
#        AllMaps: G2 Esports 2 x 1 100 Thieves  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 113: https://www.vlr.gg/475906/kr-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr2
#        Lotus: VISA KRÜ(KRÜ Esports) 12 x 14 Evil Geniuses  → Evil Geniuses
#        Icebox: VISA KRÜ(KRÜ Esports) 11 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: VISA KRÜ(KRÜ Esports) 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 114: https://www.vlr.gg/475907/g2-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-lr3
#        Lotus: G2 Esports 9 x 13 Evil Geniuses  → Evil Geniuses
#        Split: G2 Esports 13 x 7 Evil Geniuses  → G2 Esports
#        Pearl: G2 Esports 13 x 11 Evil Geniuses  → G2 Esports
#        AllMaps: G2 Esports 2 x 1 Evil Geniuses  → G2 Esports
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 115: https://www.vlr.gg/475908/mibr-vs-g2-esports-champions-tour-2025-americas-stage-1-lbf
#        Haven: MIBR 13 x 10 G2 Esports  → MIBR
#        Lotus: MIBR 13 x 15 G2 Esports  → G2 Esports
#        Split: MIBR 10 x 13 G2 Esports  → G2 Esports
#        Ascent: MIBR 8 x 13 G2 Esports  → G2 Esports
#        AllMaps: MIBR 1 x 3 G2 Esports  → G2 Esports
#      ✔ 5 linhas escritas na aba 'Placar'
#      ✔ 5 linhas salvas em 'vlr_placar2.csv'
#   → Linha 116: https://www.vlr.gg/459518/kr-esports-vs-loud-champions-tour-2025-americas-stage-1-w1
#        Fracture: VISA KRÜ(KRÜ Esports) 3 x 13 LOUD  → LOUD
#        Haven: VISA KRÜ(KRÜ Esports) 13 x 2 LOUD  → VISA KRÜ(KRÜ Esports)
#        Split: VISA KRÜ(KRÜ Esports) 13 x 10 LOUD  → VISA KRÜ(KRÜ Esports)
#        AllMaps: VISA KRÜ(KRÜ Esports) 2 x 1 LOUD  → VISA KRÜ(KRÜ Esports)
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 117: https://www.vlr.gg/459521/2game-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w1
#        Haven: 2Game Esports 11 x 13 Evil Geniuses  → Evil Geniuses
#        Lotus: 2Game Esports 8 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: 2Game Esports 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 118: https://www.vlr.gg/459522/sentinels-vs-100-thieves-champions-tour-2025-americas-stage-1-w1
#        Pearl: Sentinels 13 x 5 100 Thieves  → Sentinels
#        Haven: Sentinels 9 x 13 100 Thieves  → 100 Thieves
#        Split: Sentinels 13 x 1 100 Thieves  → Sentinels
#        AllMaps: Sentinels 2 x 1 100 Thieves  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 119: https://www.vlr.gg/459524/sentinels-vs-kr-esports-champions-tour-2025-americas-stage-1-w2
#        Lotus: Sentinels 7 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Icebox: Sentinels 8 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        AllMaps: Sentinels 0 x 2 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 120: https://www.vlr.gg/459525/100-thieves-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w2
#        Fracture: 100 Thieves 13 x 10 Evil Geniuses  → 100 Thieves
#        Haven: 100 Thieves 13 x 7 Evil Geniuses  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 Evil Geniuses  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 121: https://www.vlr.gg/459527/loud-vs-2game-esports-champions-tour-2025-americas-stage-1-w2
#        Lotus: LOUD 12 x 14 2Game Esports  → 2Game Esports
#        Pearl: LOUD 11 x 13 2Game Esports  → 2Game Esports
#        AllMaps: LOUD 0 x 2 2Game Esports  → 2Game Esports
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 122: https://www.vlr.gg/459529/evil-geniuses-vs-sentinels-champions-tour-2025-americas-stage-1-w3
#        Haven: Evil Geniuses 4 x 13 Sentinels  → Sentinels
#        Pearl: Evil Geniuses 6 x 13 Sentinels  → Sentinels
#        AllMaps: Evil Geniuses 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 123: https://www.vlr.gg/459530/100-thieves-vs-loud-champions-tour-2025-americas-stage-1-w3
#        Haven: 100 Thieves 6 x 13 LOUD  → LOUD
#        Icebox: 100 Thieves 13 x 11 LOUD  → 100 Thieves
#        Split: 100 Thieves 13 x 8 LOUD  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 1 LOUD  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 124: https://www.vlr.gg/459531/2game-esports-vs-kr-esports-champions-tour-2025-americas-stage-1-w3
#        Icebox: 2Game Esports 6 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        Ascent: 2Game Esports 13 x 6 VISA KRÜ(KRÜ Esports)  → 2Game Esports
#        Pearl: 2Game Esports 6 x 13 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#        AllMaps: 2Game Esports 1 x 2 VISA KRÜ(KRÜ Esports)  → VISA KRÜ(KRÜ Esports)
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 125: https://www.vlr.gg/459535/100-thieves-vs-2game-esports-champions-tour-2025-americas-stage-1-w4
#        Ascent: 100 Thieves 15 x 13 2Game Esports  → 100 Thieves
#        Icebox: 100 Thieves 13 x 6 2Game Esports  → 100 Thieves
#        AllMaps: 100 Thieves 2 x 0 2Game Esports  → 100 Thieves
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 126: https://www.vlr.gg/459538/sentinels-vs-loud-champions-tour-2025-americas-stage-1-w4
#        Split: Sentinels 13 x 10 LOUD  → Sentinels
#        Lotus: Sentinels 11 x 13 LOUD  → LOUD
#        Haven: Sentinels 13 x 5 LOUD  → Sentinels
#        AllMaps: Sentinels 2 x 1 LOUD  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 127: https://www.vlr.gg/459539/kr-esports-vs-evil-geniuses-champions-tour-2025-americas-stage-1-w4
#        Lotus: VISA KRÜ(KRÜ Esports) 4 x 13 Evil Geniuses  → Evil Geniuses
#        Pearl: VISA KRÜ(KRÜ Esports) 7 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: VISA KRÜ(KRÜ Esports) 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 128: https://www.vlr.gg/459543/sentinels-vs-2game-esports-champions-tour-2025-americas-stage-1-w5
#        Haven: Sentinels 13 x 4 2Game Esports  → Sentinels
#        Pearl: Sentinels 13 x 5 2Game Esports  → Sentinels
#        AllMaps: Sentinels 2 x 0 2Game Esports  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 129: https://www.vlr.gg/459544/kr-esports-vs-100-thieves-champions-tour-2025-americas-stage-1-w5
#        Fracture: VISA KRÜ(KRÜ Esports) 13 x 10 100 Thieves  → VISA KRÜ(KRÜ Esports)
#        Icebox: VISA KRÜ(KRÜ Esports) 13 x 9 100 Thieves  → VISA KRÜ(KRÜ Esports)
#        AllMaps: VISA KRÜ(KRÜ Esports) 2 x 0 100 Thieves  → VISA KRÜ(KRÜ Esports)
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 130: https://www.vlr.gg/459545/evil-geniuses-vs-loud-champions-tour-2025-americas-stage-1-w5
#        Lotus: Evil Geniuses 11 x 13 LOUD  → LOUD
#        Pearl: Evil Geniuses 14 x 12 LOUD  → Evil Geniuses
#        Split: Evil Geniuses 13 x 11 LOUD  → Evil Geniuses
#        AllMaps: Evil Geniuses 2 x 1 LOUD  → Evil Geniuses
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 131: https://www.vlr.gg/459546/leviat-n-vs-nrg-esports-champions-tour-2025-americas-stage-1-w5
#        Fracture: LEVIATÁN 13 x 15 NRG  → NRG
#        Icebox: LEVIATÁN 8 x 13 NRG  → NRG
#        AllMaps: LEVIATÁN 0 x 2 NRG  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 132: https://www.vlr.gg/459542/mibr-vs-furia-champions-tour-2025-americas-stage-1-w5
#        Icebox: MIBR 13 x 3 FURIA  → MIBR
#        Ascent: MIBR 9 x 13 FURIA  → FURIA
#        Split: MIBR 13 x 8 FURIA  → MIBR
#        AllMaps: MIBR 2 x 1 FURIA  → MIBR
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 133: https://www.vlr.gg/459541/g2-esports-vs-cloud9-champions-tour-2025-americas-stage-1-w5
#        Icebox: G2 Esports 13 x 5 Cloud9  → G2 Esports
#        Haven: G2 Esports 4 x 13 Cloud9  → Cloud9
#        Pearl: G2 Esports 13 x 11 Cloud9  → G2 Esports
# ...
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 270: https://www.vlr.gg/183786/nrg-esports-vs-mibr-champions-tour-2023-americas-league-w3
#        Icebox: NRG 10 x 13 MIBR  → MIBR
#        Pearl: NRG 16 x 14 MIBR  → NRG
#        Split: NRG 14 x 16 MIBR  → MIBR
#        AllMaps: NRG 1 x 2 MIBR  → MIBR
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 271: https://www.vlr.gg/183787/leviat-n-vs-sentinels-champions-tour-2023-americas-league-w3
#        Split: LEVIATÁN 14 x 12 Sentinels  → LEVIATÁN
#        Ascent: LEVIATÁN 11 x 13 Sentinels  → Sentinels
#        Pearl: LEVIATÁN 13 x 4 Sentinels  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 1 Sentinels  → LEVIATÁN
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 272: https://www.vlr.gg/183788/evil-geniuses-vs-kr-esports-champions-tour-2023-americas-league-w3
#        Pearl: Evil Geniuses 13 x 11 KRÜ Esports  → Evil Geniuses
#        Ascent: Evil Geniuses 11 x 13 KRÜ Esports  → KRÜ Esports
#        Fracture: Evil Geniuses 13 x 7 KRÜ Esports  → Evil Geniuses
#        AllMaps: Evil Geniuses 2 x 1 KRÜ Esports  → Evil Geniuses
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 273: https://www.vlr.gg/183789/loud-vs-furia-champions-tour-2023-americas-league-w3
#        Split: LOUD 13 x 9 FURIA  → LOUD
#        Icebox: LOUD 13 x 4 FURIA  → LOUD
#        AllMaps: LOUD 2 x 0 FURIA  → LOUD
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 274: https://www.vlr.gg/183791/loud-vs-sentinels-champions-tour-2023-americas-league-w4
#        Pearl: LOUD 6 x 13 Sentinels  → Sentinels
#        Haven: LOUD 13 x 11 Sentinels  → LOUD
#        Ascent: LOUD 13 x 8 Sentinels  → LOUD
#        AllMaps: LOUD 2 x 1 Sentinels  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 275: https://www.vlr.gg/183792/leviat-n-vs-mibr-champions-tour-2023-americas-league-w4
#        Pearl: LEVIATÁN 13 x 4 MIBR  → LEVIATÁN
#        Icebox: LEVIATÁN 13 x 3 MIBR  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 0 MIBR  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 276: https://www.vlr.gg/183793/kr-esports-vs-100-thieves-champions-tour-2023-americas-league-w4
#        Ascent: KRÜ Esports 13 x 4 100 Thieves  → KRÜ Esports
#        Split: KRÜ Esports 11 x 13 100 Thieves  → 100 Thieves
#        Fracture: KRÜ Esports 5 x 13 100 Thieves  → 100 Thieves
#        AllMaps: KRÜ Esports 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 277: https://www.vlr.gg/183794/evil-geniuses-vs-furia-champions-tour-2023-americas-league-w4
#        Ascent: Evil Geniuses 13 x 15 FURIA  → FURIA
#        Fracture: Evil Geniuses 13 x 7 FURIA  → Evil Geniuses
#        Haven: Evil Geniuses 10 x 13 FURIA  → FURIA
#        AllMaps: Evil Geniuses 1 x 2 FURIA  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 278: https://www.vlr.gg/183795/nrg-esports-vs-cloud9-champions-tour-2023-americas-league-w4
#        Haven: NRG 13 x 8 Cloud9  → NRG
#        Pearl: NRG 9 x 13 Cloud9  → Cloud9
#        Ascent: NRG 7 x 13 Cloud9  → Cloud9
#        AllMaps: NRG 1 x 2 Cloud9  → Cloud9
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 279: https://www.vlr.gg/183796/mibr-vs-sentinels-champions-tour-2023-americas-league-w4
#        Pearl: MIBR 5 x 13 Sentinels  → Sentinels
#        Fracture: MIBR 6 x 13 Sentinels  → Sentinels
#        AllMaps: MIBR 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 280: https://www.vlr.gg/183797/leviat-n-vs-100-thieves-champions-tour-2023-americas-league-w4
#        Icebox: LEVIATÁN 15 x 13 100 Thieves  → LEVIATÁN
#        Haven: LEVIATÁN 11 x 13 100 Thieves  → 100 Thieves
#        Lotus: LEVIATÁN 11 x 13 100 Thieves  → 100 Thieves
#        AllMaps: LEVIATÁN 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 281: https://www.vlr.gg/183798/evil-geniuses-vs-loud-champions-tour-2023-americas-league-w4
#        Split: Evil Geniuses 13 x 3 LOUD  → Evil Geniuses
#        Haven: Evil Geniuses 10 x 13 LOUD  → LOUD
#        Pearl: Evil Geniuses 0 x 13 LOUD  → LOUD
#        AllMaps: Evil Geniuses 1 x 2 LOUD  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 282: https://www.vlr.gg/183799/cloud9-vs-furia-champions-tour-2023-americas-league-w4
#        Ascent: Cloud9 13 x 8 FURIA  → Cloud9
#        Fracture: Cloud9 13 x 9 FURIA  → Cloud9
#        AllMaps: Cloud9 2 x 0 FURIA  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 283: https://www.vlr.gg/183800/nrg-esports-vs-kr-esports-champions-tour-2023-americas-league-w4
#        Haven: NRG 13 x 10 KRÜ Esports  → NRG
#        Ascent: NRG 13 x 4 KRÜ Esports  → NRG
#        AllMaps: NRG 2 x 0 KRÜ Esports  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 284: https://www.vlr.gg/183801/nrg-esports-vs-100-thieves-champions-tour-2023-americas-league-w5
#        Bind: NRG 13 x 7 100 Thieves  → NRG
#        Fracture: NRG 13 x 3 100 Thieves  → NRG
#        AllMaps: NRG 2 x 0 100 Thieves  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 285: https://www.vlr.gg/183802/mibr-vs-furia-champions-tour-2023-americas-league-w5
#        Pearl: MIBR 11 x 13 FURIA  → FURIA
#        Split: MIBR 7 x 13 FURIA  → FURIA
#        AllMaps: MIBR 0 x 2 FURIA  → FURIA
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 286: https://www.vlr.gg/183803/cloud9-vs-sentinels-champions-tour-2023-americas-league-w5
#        Lotus: Cloud9 13 x 4 Sentinels  → Cloud9
#        Fracture: Cloud9 13 x 6 Sentinels  → Cloud9
#        AllMaps: Cloud9 2 x 0 Sentinels  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 287: https://www.vlr.gg/183804/leviat-n-vs-evil-geniuses-champions-tour-2023-americas-league-w5
#        Split: LEVIATÁN 10 x 13 Evil Geniuses  → Evil Geniuses
#        Pearl: LEVIATÁN 13 x 10 Evil Geniuses  → LEVIATÁN
#        Ascent: LEVIATÁN 10 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: LEVIATÁN 1 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 288: https://www.vlr.gg/183805/loud-vs-kr-esports-champions-tour-2023-americas-league-w5
#        Pearl: LOUD 10 x 13 KRÜ Esports  → KRÜ Esports
#        Ascent: LOUD 13 x 11 KRÜ Esports  → LOUD
#        Split: LOUD 13 x 10 KRÜ Esports  → LOUD
#        AllMaps: LOUD 2 x 1 KRÜ Esports  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 289: https://www.vlr.gg/183807/evil-geniuses-vs-sentinels-champions-tour-2023-americas-league-w6
#        Fracture: Evil Geniuses 13 x 6 Sentinels  → Evil Geniuses
#        Pearl: Evil Geniuses 13 x 5 Sentinels  → Evil Geniuses
#        AllMaps: Evil Geniuses 2 x 0 Sentinels  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 290: https://www.vlr.gg/183808/cloud9-vs-mibr-champions-tour-2023-americas-league-w6
#        Split: Cloud9 13 x 5 MIBR  → Cloud9
#        Lotus: Cloud9 13 x 4 MIBR  → Cloud9
#        AllMaps: Cloud9 2 x 0 MIBR  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 291: https://www.vlr.gg/183809/loud-vs-100-thieves-champions-tour-2023-americas-league-w6
#        Ascent: LOUD 13 x 5 100 Thieves  → LOUD
#        Split: LOUD 15 x 13 100 Thieves  → LOUD
#        AllMaps: LOUD 2 x 0 100 Thieves  → LOUD
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 292: https://www.vlr.gg/183810/leviat-n-vs-kr-esports-champions-tour-2023-americas-league-w6
#        Haven: LEVIATÁN 13 x 4 KRÜ Esports  → LEVIATÁN
#        Split: LEVIATÁN 13 x 4 KRÜ Esports  → LEVIATÁN
#        AllMaps: LEVIATÁN 2 x 0 KRÜ Esports  → LEVIATÁN
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 293: https://www.vlr.gg/183811/nrg-esports-vs-furia-champions-tour-2023-americas-league-w6
#        Bind: NRG 13 x 11 FURIA  → NRG
#        Haven: NRG 11 x 13 FURIA  → FURIA
#        Pearl: NRG 13 x 6 FURIA  → NRG
#        AllMaps: NRG 2 x 1 FURIA  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 294: https://www.vlr.gg/183812/furia-vs-100-thieves-champions-tour-2023-americas-league-w7
#        Pearl: FURIA 13 x 10 100 Thieves  → FURIA
#        Fracture: FURIA 7 x 13 100 Thieves  → 100 Thieves
#        Haven: FURIA 11 x 13 100 Thieves  → 100 Thieves
#        AllMaps: FURIA 1 x 2 100 Thieves  → 100 Thieves
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 295: https://www.vlr.gg/183813/evil-geniuses-vs-mibr-champions-tour-2023-americas-league-w7
#        Lotus: Evil Geniuses 13 x 2 MIBR  → Evil Geniuses
#        Fracture: Evil Geniuses 13 x 5 MIBR  → Evil Geniuses
#        AllMaps: Evil Geniuses 2 x 0 MIBR  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 296: https://www.vlr.gg/183814/kr-esports-vs-sentinels-champions-tour-2023-americas-league-w7
#        Lotus: KRÜ Esports 12 x 14 Sentinels  → Sentinels
#        Bind: KRÜ Esports 10 x 13 Sentinels  → Sentinels
#        AllMaps: KRÜ Esports 0 x 2 Sentinels  → Sentinels
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 297: https://www.vlr.gg/183815/nrg-esports-vs-loud-champions-tour-2023-americas-league-w7
#        Split: NRG 13 x 5 LOUD  → NRG
#        Pearl: NRG 13 x 9 LOUD  → NRG
#        AllMaps: NRG 2 x 0 LOUD  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 298: https://www.vlr.gg/183816/leviat-n-vs-cloud9-champions-tour-2023-americas-league-w7
#        Lotus: LEVIATÁN 7 x 13 Cloud9  → Cloud9
#        Haven: LEVIATÁN 4 x 13 Cloud9  → Cloud9
#        AllMaps: LEVIATÁN 0 x 2 Cloud9  → Cloud9
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 299: https://www.vlr.gg/184032/sentinels-vs-furia-champions-tour-2023-americas-league-w8
#        Split: Sentinels 13 x 7 FURIA  → Sentinels
#        Haven: Sentinels 5 x 13 FURIA  → FURIA
#        Bind: Sentinels 19 x 17 FURIA  → Sentinels
#        AllMaps: Sentinels 2 x 1 FURIA  → Sentinels
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 300: https://www.vlr.gg/184033/nrg-esports-vs-evil-geniuses-champions-tour-2023-americas-league-w8
#        Bind: NRG 13 x 9 Evil Geniuses  → NRG
#        Split: NRG 13 x 7 Evil Geniuses  → NRG
#        AllMaps: NRG 2 x 0 Evil Geniuses  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 301: https://www.vlr.gg/184034/cloud9-vs-kr-esports-champions-tour-2023-americas-league-w8
#        Lotus: Cloud9 15 x 13 KRÜ Esports  → Cloud9
#        Ascent: Cloud9 6 x 13 KRÜ Esports  → KRÜ Esports
#        Split: Cloud9 13 x 9 KRÜ Esports  → Cloud9
#        AllMaps: Cloud9 2 x 1 KRÜ Esports  → Cloud9
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 302: https://www.vlr.gg/184035/leviat-n-vs-loud-champions-tour-2023-americas-league-w8
#        Haven: LEVIATÁN 7 x 13 LOUD  → LOUD
#        Ascent: LEVIATÁN 5 x 13 LOUD  → LOUD
#        AllMaps: LEVIATÁN 0 x 2 LOUD  → LOUD
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 303: https://www.vlr.gg/184036/mibr-vs-100-thieves-champions-tour-2023-americas-league-w8
#        Fracture: MIBR 13 x 6 100 Thieves  → MIBR
#        Pearl: MIBR 12 x 14 100 Thieves  → 100 Thieves
#        Lotus: MIBR 13 x 7 100 Thieves  → MIBR
#        AllMaps: MIBR 2 x 1 100 Thieves  → MIBR
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 304: https://www.vlr.gg/189050/leviat-n-vs-furia-champions-tour-2023-americas-league-ur1
#        Ascent: LEVIATÁN 5 x 13 FURIA  → FURIA
#        Pearl: LEVIATÁN 20 x 18 FURIA  → LEVIATÁN
#        Bind: LEVIATÁN 6 x 13 FURIA  → FURIA
#        AllMaps: LEVIATÁN 1 x 2 FURIA  → FURIA
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 305: https://www.vlr.gg/189051/nrg-esports-vs-evil-geniuses-champions-tour-2023-americas-league-ur1
#        Haven: NRG 13 x 11 Evil Geniuses  → NRG
#        Split: NRG 13 x 15 Evil Geniuses  → Evil Geniuses
#        Ascent: NRG 7 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: NRG 1 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 306: https://www.vlr.gg/189052/loud-vs-furia-champions-tour-2023-americas-league-ubsf
#        Haven: LOUD 13 x 4 FURIA  → LOUD
#        Ascent: LOUD 13 x 5 FURIA  → LOUD
#        AllMaps: LOUD 2 x 0 FURIA  → LOUD
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 307: https://www.vlr.gg/189053/cloud9-vs-evil-geniuses-champions-tour-2023-americas-league-ubsf
#        Fracture: Cloud9 5 x 13 Evil Geniuses  → Evil Geniuses
#        Bind: Cloud9 2 x 13 Evil Geniuses  → Evil Geniuses
#        AllMaps: Cloud9 0 x 2 Evil Geniuses  → Evil Geniuses
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 308: https://www.vlr.gg/189056/cloud9-vs-leviat-n-champions-tour-2023-americas-league-lr1
#        Haven: Cloud9 13 x 8 LEVIATÁN  → Cloud9
#        Lotus: Cloud9 10 x 13 LEVIATÁN  → LEVIATÁN
#        Ascent: Cloud9 13 x 4 LEVIATÁN  → Cloud9
#        AllMaps: Cloud9 2 x 1 LEVIATÁN  → Cloud9
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 309: https://www.vlr.gg/189057/furia-vs-nrg-esports-champions-tour-2023-americas-league-lr1
#        Bind: FURIA 9 x 13 NRG  → NRG
#        Haven: FURIA 10 x 13 NRG  → NRG
#        AllMaps: FURIA 0 x 2 NRG  → NRG
#      ✔ 3 linhas escritas na aba 'Placar'
#      ✔ 3 linhas salvas em 'vlr_placar2.csv'
#   → Linha 310: https://www.vlr.gg/189054/loud-vs-evil-geniuses-champions-tour-2023-americas-league-ubf
#        Fracture: LOUD 13 x 9 Evil Geniuses  → LOUD
#        Ascent: LOUD 11 x 13 Evil Geniuses  → Evil Geniuses
#        Bind: LOUD 13 x 3 Evil Geniuses  → LOUD
#        AllMaps: LOUD 2 x 1 Evil Geniuses  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 311: https://www.vlr.gg/189058/cloud9-vs-nrg-esports-champions-tour-2023-americas-league-lr2
#        Pearl: Cloud9 13 x 10 NRG  → Cloud9
#        Lotus: Cloud9 9 x 13 NRG  → NRG
#        Haven: Cloud9 12 x 14 NRG  → NRG
#        AllMaps: Cloud9 1 x 2 NRG  → NRG
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#   → Linha 312: https://www.vlr.gg/189059/evil-geniuses-vs-nrg-esports-champions-tour-2023-americas-league-lbf
#        Haven: Evil Geniuses 13 x 11 NRG  → Evil Geniuses
#        Ascent: Evil Geniuses 8 x 13 NRG  → NRG
#        Lotus: Evil Geniuses 10 x 13 NRG  → NRG
#        Split: Evil Geniuses 4 x 13 NRG  → NRG
#        AllMaps: Evil Geniuses 1 x 3 NRG  → NRG
#      ✔ 5 linhas escritas na aba 'Placar'
#      ✔ 5 linhas salvas em 'vlr_placar2.csv'
#   → Linha 313: https://www.vlr.gg/189055/loud-vs-nrg-esports-champions-tour-2023-americas-league-gf
#        Ascent: LOUD 13 x 9 NRG  → LOUD
#        Bind: LOUD 13 x 11 NRG  → LOUD
#        Fracture: LOUD 13 x 11 NRG  → LOUD
#        AllMaps: LOUD 3 x 0 NRG  → LOUD
#      ✔ 4 linhas escritas na aba 'Placar'
#      ✔ 4 linhas salvas em 'vlr_placar2.csv'
#
# ✅ Finalizado! Dados em 'vlr_placar2.csv' e na aba 'Placar'.

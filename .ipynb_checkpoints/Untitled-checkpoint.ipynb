# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
df_placar2 = pd.read_csv("vlr_placar2.csv")
df_stats2 = pd.read_csv("vlr_stats2.csv")
df_merged = pd.read_csv("merged_status_placar.csv")
df_jog_map = pd.read_csv("jogador_por_mapas.csv")
df_matchups = pd.read_csv("matchups_score.csv")

# %%
df_placar2.head(3)
# Out:
#                                                  URL     Mapa Time1  Mapas_T1  \
# 0  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...    Haven  LOUD       NaN
# 1  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...    Abyss  LOUD       NaN
# 2  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...  AllMaps  LOUD       0.0
#
#    Score_T1   Time2  Mapas_T2  Score_T2 Vencedor
# 0         7  Cloud9       NaN        13   Cloud9
# 1        11  Cloud9       NaN        13   Cloud9
# 2        18  Cloud9       2.0        26   Cloud9

# %%
df_stats2.head(3)
# Out:
#                                                  URL  Mapa_Num   Mapa  \
# 0  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
# 1  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
# 2  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
#
#     Jogador  Time Agente     R  ACS   K   D  A  +/-  KAST  ADR  HS%  FK  FD  \
# 0    Darker  LOUD  Viper  1.12  256  18  16  6    2    70  166   30   2   1
# 1  cauanzin  LOUD   Sova  0.98  209  15  13  3    2    75  152   26   0   1
# 2    Virtyy  LOUD   Yoru  0.70  178  14  16  4   -2    55  102   35   2   3
#
#    +/-_FK_FD
# 0          1
# 1         -1
# 2         -1

# %%
df_merged.head(3)
# Out:
#                                                  URL  Mapa_Num   Mapa  \
# 0  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
# 1  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
# 2  https://www.vlr.gg/596398/loud-vs-cloud9-vct-2...         0  Haven
#
#     Jogador  Time Agente     R  ACS   K   D  ...  HS%  FK  FD  +/-_FK_FD  \
# 0    Darker  LOUD  Viper  1.12  256  18  16  ...   30   2   1          1
# 1  cauanzin  LOUD   Sova  0.98  209  15  13  ...   26   0   1         -1
# 2    Virtyy  LOUD   Yoru  0.70  178  14  16  ...   35   2   3         -1
#
#    Vencedor  Adversario  Score_Time  Score_Adv Mapas_Time Mapas_Adv
# 0    Cloud9      Cloud9         7.0       13.0        0.0       2.0
# 1    Cloud9      Cloud9         7.0       13.0        0.0       2.0
# 2    Cloud9      Cloud9         7.0       13.0        0.0       2.0
#
# [3 rows x 24 columns]

# %%
df_jog_map.head(3)
# Out:
#        Jogador  Time   Mapa      R    ACS   K   D  A  +/-  KAST    ADR   HS%  \
# 0  infiltrator   KRÜ  Abyss  1.360  293.5  43  30  6   13  87.5  186.0  32.0
# 1        lukxo  LOUD  Abyss  1.443  279.7  77  44  8   33  75.7  174.7  34.7
# 2         vora  100T  Abyss  1.385  255.5  33  22  6   11  82.0  163.5  28.5
#
#    FK  FD  +/-_FK_FD  Jogos  Wins  WinRate  Impacto
# 0   5   2          3      2     0      0.0    1.383
# 1  12  10          2      3     0      0.0    1.363
# 2   2   2          0      2     1      0.5    1.304

# %%
df_matchups.head(3)
# Out:
#           Time     Adversario  Vitorias  Derrotas  Mapas  WinRate
# 0  100 Thieves  2Game Esports         2         0      2    100.0
# 1  100 Thieves         Cloud9         2         3      5     40.0
# 2  100 Thieves  Evil Geniuses         6         0      6    100.0

# %%
TIME_A = "MIBR"
TIME_B = "EG"
MAPA   = "Abyss"
# Definir o time quais sao os jogadores 

# RESULTADO
print("=" * 50)
print(f"  {TIME_A}  vs  {TIME_B}  —  {MAPA}")
print("=" * 50)
print(f"  Vencedor previsto : {vencedor_prev}")
print(f"  {TIME_A:<20} {prob_A*100:.1f}%")
print(f"  {TIME_B:<20} {prob_B*100:.1f}%")
print("-" * 50)
print(f"  Acurácia do modelo (CV 5-fold): {acc_media*100:.1f}%")
print(f"  Amostras de treino: {len(df_train)}")
print("=" * 50)
# Out:
# ...
#   MIBR  vs  EG  —  Abyss
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       7 print(f"  {TIME_A}  vs  {TIME_B}  —  {MAPA}")
#       8 print("=" * 50)
# ----> 9 print(f"  Vencedor previsto : {vencedor_prev}")
#      10 print(f"  {TIME_A:<20} {prob_A*100:.1f}%")
#      11 print(f"  {TIME_B:<20} {prob_B*100:.1f}%")
#
# NameError: name 'vencedor_prev' is not defined

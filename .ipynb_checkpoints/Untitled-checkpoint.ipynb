# %%
import pandas as pd


#pd.set_option('display.max_columns', None)
df_impc = pd.read_csv("df_impacto_cada_mapa.csv")

# %%
df_impc.head(20)
# Out:
#      Mapa   Jogador  Time   Agente     R    ACS   K   D   A  +/-  KAST    ADR  \
# 0   Haven    Darker  LOUD    Viper  1.12  256.0  18  16   6    2  70.0  166.0
# 1   Haven  cauanzin  LOUD     Sova  0.98  209.0  15  13   3    2  75.0  152.0
# 2   Haven    Virtyy  LOUD     Yoru  0.70  178.0  14  16   4   -2  55.0  102.0
# 3   Haven   pANcada  LOUD     Omen  0.67  145.0  11  13   1   -2  65.0   99.0
# 4   Haven     lukxo  LOUD  Killjoy  0.65  192.0  13  16   3   -3  60.0  125.0
# 5   Haven       OXY    C9     Neon  1.44  282.0  21  14   2    7  80.0  169.0
# 6   Haven     penny    C9    Viper  1.23  203.0  15  12   7    3  80.0  133.0
# 7   Haven       v1c    C9     Omen  1.04  198.0  14  13   7    1  80.0  139.0
# 8   Haven    Xeppaa    C9     Sova  1.01  185.0  13  16   9   -3  90.0  125.0
# 9   Haven   Zellsis    C9  Killjoy  0.82  166.0  11  16   1   -5  70.0  124.0
# 10  Abyss     lukxo  LOUD  Chamber  1.46  297.0  27  16   3   11  75.0  175.0
# 11  Abyss    Darker  LOUD    Astra  0.95  166.0  15  16   8   -1  75.0  101.0
# 12  Abyss   pANcada  LOUD   Harbor  0.81  114.0  11  13   9   -2  79.0   66.0
# 13  Abyss  cauanzin  LOUD     Sova  0.73  166.0  13  20   8   -7  67.0  116.0
# 14  Abyss    Virtyy  LOUD     Yoru  0.69  170.0  13  19   3   -6  63.0  113.0
# 15  Abyss     penny    C9     Veto  1.26  214.0  19  14   7    5  83.0  151.0
# 16  Abyss    Xeppaa    C9     Sova  1.15  213.0  19  14   6    5  79.0  137.0
# 17  Abyss       v1c    C9    Astra  1.07  219.0  17  16   8    1  83.0  124.0
# 18  Abyss   Zellsis    C9   Breach  0.90  161.0  12  17  13   -5  96.0  101.0
# 19  Abyss       OXY    C9   Waylay  0.84  190.0  17  18   2   -1  63.0  122.0
#
#      HS%   FK   FD  +/-_FK_FD Time1  Score_T1 Time2  Score_T2  target  Impacto
# 0   30.0  2.0  1.0        1.0  LOUD         7    C9        13       0    0.821
# 1   26.0  0.0  1.0       -1.0  LOUD         7    C9        13       0    0.734
# 2   35.0  2.0  3.0       -1.0  LOUD         7    C9        13       0    0.492
# 3   27.0  0.0  3.0       -3.0  LOUD         7    C9        13       0    0.478
# 4   35.0  4.0  4.0        0.0  LOUD         7    C9        13       0    0.538
# 5   29.0  5.0  2.0        3.0  LOUD         7    C9        13       1    0.885
# 6   23.0  3.0  2.0        1.0  LOUD         7    C9        13       1    0.793
# 7   26.0  1.0  2.0       -1.0  LOUD         7    C9        13       1    0.735
# 8   21.0  0.0  0.0        0.0  LOUD         7    C9        13       1    0.605
# 9   20.0  3.0  2.0        1.0  LOUD         7    C9        13       1    0.562
# 10  34.0  4.0  2.0        2.0  LOUD        11    C9        13       0    0.892
# 11  31.0  1.0  3.0       -2.0  LOUD        11    C9        13       0    0.540
# 12  63.0  1.0  1.0        0.0  LOUD        11    C9        13       0    0.534
# 13  29.0  0.0  5.0       -5.0  LOUD        11    C9        13       0    0.511
# 14  21.0  4.0  3.0        1.0  LOUD        11    C9        13       0    0.532
# 15  26.0  3.0  5.0       -2.0  LOUD        11    C9        13       1    0.779
# 16  29.0  0.0  0.0        0.0  LOUD        11    C9        13       1    0.777
# 17  22.0  5.0  1.0        4.0  LOUD        11    C9        13       1    0.781
# 18  29.0  2.0  0.0        2.0  LOUD        11    C9        13       1    0.608
# 19  44.0  4.0  4.0        0.0  LOUD        11    C9        13       1    0.570

# %%
df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'lukxo') &
    (df_impc['Agente'] == 'Cypher')
]
teste = df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'lukxo') &
    (df_impc['Agente'] == 'Cypher')
]
teste
# Out:
#        Mapa Jogador  Time  Agente     R    ACS   K   D  A  +/-  KAST    ADR   HS%   FK   FD  +/-_FK_FD Time1  Score_T1 Time2  Score_T2  target  Impacto
# 1600  Haven   lukxo  LOUD  Cypher  1.01  204.0  15  14  2    1  80.0  139.0  43.0  3.0  2.0        1.0  LOUD         7   KRU        13       0    0.798
# 1705  Haven   lukxo  LOUD  Cypher  1.00  195.0  12  10  4    2  71.0  124.0  18.0  2.0  1.0        1.0   NRG        13  LOUD         4       0    0.736
# 2296  Haven   lukxo  LOUD  Cypher  1.34  288.0  20  11  3    9  79.0  175.0  36.0  4.0  0.0        4.0  100T         6  LOUD        13       1    0.888
# 2395  Haven   lukxo  LOUD  Cypher  1.17  303.0  18  15  3    3  61.0  198.0  25.0  3.0  1.0        2.0   SEN        13  LOUD         5       0    0.837

# %%
teste = df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'Darker')
]
teste
# Out:
#        Mapa Jogador  Time   Agente     R    ACS   K   D  A  +/-  KAST    ADR   HS%   FK   FD  +/-_FK_FD Time1  Score_T1 Time2  Score_T2  target  Impacto
# 0     Haven  Darker  LOUD    Viper  1.12  256.0  18  16  6    2  70.0  166.0  30.0  2.0  1.0        1.0  LOUD         7    C9        13       0    0.821
# 410   Haven  Darker  LOUD    Viper  1.20  288.0  18  15  4    3  78.0  167.0  29.0  3.0  2.0        1.0  LOUD         5    EG        13       0    0.857
# 3559  Haven  Darker  LOUD    Viper  0.55  151.0  10  18  6   -8  52.0  111.0  29.0  0.0  3.0       -3.0  MIBR        13  LOUD        10       0    0.456
# 3599  Haven  Darker  LOUD    Viper  0.56  156.0  11  19  5   -8  64.0  111.0  32.0  1.0  3.0       -2.0    G2        13  LOUD         9       0    0.484
# 3761  Haven  Darker  LOUD  Phoenix  1.27  259.0  22  18  8    4  65.0  162.0  22.0  1.0  1.0        0.0  LOUD        13   LEV        10       1    0.795

# %%
t1 = pd.concat([

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'lukxo') &
    (df_impc['Agente'] == 'Chamber')&
    (df_impc['Time2'] == 'LEV')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'cauanzin') &
    (df_impc['Agente'] == 'Sova')&
    (df_impc['Time2'] == 'LEV')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'erde') &
    (df_impc['Agente'] == 'Omen')&
    (df_impc['Time2'] == 'LEV')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'Darker') &
    (df_impc['Agente'] == 'Phoenix')&
    (df_impc['Time2'] == 'LEV')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'Virtyy') &
    (df_impc['Agente'] == 'Neon')&
    (df_impc['Time2'] == 'LEV')
]


], ignore_index=True)

t1
# Out:
#     Mapa   Jogador  Time   Agente     R    ACS   K   D   A  +/-  KAST    ADR   HS%   FK   FD  +/-_FK_FD Time1  Score_T1 Time2  Score_T2  target  Impacto
# 0  Haven     lukxo  LOUD  Chamber  0.83  131.0  11  13   4   -2  61.0   87.0  12.0  2.0  5.0       -3.0  LOUD        13   LEV        10       1    0.450
# 1  Haven  cauanzin  LOUD     Sova  1.01  166.0  11  14   8   -3  70.0  122.0  22.0  2.0  2.0        0.0  LOUD        13   LEV        10       1    0.562
# 2  Haven      erde  LOUD     Omen  1.50  242.0  20  12  14    8  96.0  150.0  16.0  1.0  1.0        0.0  LOUD        13   LEV        10       1    0.843
# 3  Haven    Darker  LOUD  Phoenix  1.27  259.0  22  18   8    4  65.0  162.0  22.0  1.0  1.0        0.0  LOUD        13   LEV        10       1    0.795
# 4  Haven    Virtyy  LOUD     Neon  0.77  181.0  14  20   8   -6  78.0  112.0  11.0  3.0  5.0       -2.0  LOUD        13   LEV        10       1    0.510

# %%
t2 = pd.concat([

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'Neon') &
    (df_impc['Agente'] == 'Chamber')&
    (df_impc['Time1'] == 'LOUD')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'blowz') &
    (df_impc['Agente'] == 'Sova')&
    (df_impc['Time1'] == 'LOUD')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'kiNgg') &
    (df_impc['Agente'] == 'Astra')&
    (df_impc['Time1'] == 'LOUD')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'Sato') &
    (df_impc['Agente'] == 'Phoenix')&
    (df_impc['Time1'] == 'LOUD')
],

df_impc[
    (df_impc['Mapa'] == 'Haven') &
    (df_impc['Jogador'] == 'spike') &
    (df_impc['Agente'] == 'Neon')&
    (df_impc['Time1'] == 'LOUD')
]


], ignore_index=True)

t2
# Out:
#     Mapa Jogador Time   Agente     R    ACS   K   D   A  +/-  KAST    ADR   HS%   FK   FD  +/-_FK_FD Time1  Score_T1 Time2  Score_T2  target  Impacto
# 0  Haven    Neon  LEV  Chamber  1.18  208.0  16  13   5    3  78.0  147.0  18.0  5.0  2.0        3.0  LOUD        13   LEV        10       0    0.788
# 1  Haven   blowz  LEV     Sova  0.90  169.0  15  15   6    0  83.0  108.0  43.0  2.0  0.0        2.0  LOUD        13   LEV        10       0    0.682
# 2  Haven   kiNgg  LEV    Astra  0.78  128.0   9  13   8   -4  70.0   94.0  38.0  0.0  0.0        0.0  LOUD        13   LEV        10       0    0.521
# 3  Haven    Sato  LEV  Phoenix  1.27  262.0  21  17  10    4  87.0  171.0  42.0  2.0  2.0        0.0  LOUD        13   LEV        10       0    0.863
# 4  Haven   spike  LEV     Neon  0.74  210.0  16  20   9   -4  65.0  122.0  27.0  5.0  5.0        0.0  LOUD        13   LEV        10       0    0.553

# %%
def gerar_time_aleatorio(df, n=5, seed=None):
    time = df.sample(n=n, random_state=seed).reset_index(drop=True)

    cols_soma = [
        'K', 'D', 'A', '+/-',
        'FK', 'FD', '+/-_FK_FD'
    ]

    cols_media = [
        'R', 'ACS', 'KAST',
        'ADR', 'HS%', 'Impacto'
    ]

    soma = time[cols_soma].sum()
    media = time[cols_media].mean()

    total = pd.concat([soma, media])

    total['Jogador'] = 'TOTAL'
    total['Mapa'] = '-'
    total['Time'] = '-'
    total['Agente'] = '-'
    total['Score_T1'] = '-'
    total['Score_T2'] = '-'
    total['target'] = '-'

    time = pd.concat([time, total.to_frame().T], ignore_index=True)

    return time


time = gerar_time_aleatorio(df_impc)
time
# Out:
#      Mapa  Jogador  Time  Agente      R    ACS     K     D     A   +/-  KAST    ADR   HS%    FK    FD +/-_FK_FD Time1 Score_T1 Time2 Score_T2 target Impacto
# 0   Lotus  murizzz  MIBR   Viper   0.27   89.0     4    14     3   -10  40.0   61.0  17.0   0.0   3.0      -3.0    EG       13  MIBR        2      0   0.356
# 1   Split      OXY    C9    Raze   1.05  265.0    20    18     2     2  62.0  166.0  35.0   5.0   6.0      -1.0    C9        8  MIBR       13      0   0.767
# 2  Ascent    Asuna  100T    Kayo   0.77  180.0    10    15     2    -5  65.0  131.0  20.0   2.0   1.0       1.0   KRU       13  100T        4      0   0.559
# 3   Split    nerve   FUR   Viper   0.86  168.0    14    14     3     0  67.0  113.0  23.0   1.0   2.0      -1.0  MIBR        8   FUR       13      1   0.587
# 4   Split  FiNESSE   NRG  Breach   0.54  142.0    12    23    11   -11  73.0   98.0  16.0   3.0   1.0       2.0   NRG       14  MIBR       16      0   0.502
# 5       -    TOTAL     -       -  0.698  168.8  60.0  84.0  21.0 -24.0  61.4  113.8  22.2  11.0  13.0      -2.0   NaN        -   NaN        -      -  0.5542
